# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 40px; color: black; font-weight: bold;">
# Pyro 101
# </div>
#
# - Parameter point estimate
# - SVI
# - MCMC

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
from tqdm import tqdm
import torchsde

import pyro
import pyro.distributions as dist
import pyro.distributions.constraints as constraints
from pyro.infer import MCMC, NUTS
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

# %%
def seed_everything(seed=42):
    """
    Set seed for reproducibility.
    """
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
# NB Warning : setting the defualt_device to CUDA creates a device conflict
# when using a DataLoader, as it uses a CPU-generator for shuffling
torch.set_default_device(device)

print(f"Using {device}")
if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Total GPU Memory:', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')

torch.set_default_dtype(torch.float32)
# Out:
# Using cuda
# GPU Name: NVIDIA GeForce RTX 3080 Ti
# Total GPU Memory: 11.8 GB

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 30px; color: black; font-weight: bold;">
# 0 : Generate synthetic data
# </div>

# %%
a = torch.tensor([2.0])
b = torch.tensor([-1.0])
noise = torch.tensor([0.1])

N_POINTS = 100

X = torch.linspace(0.0, 1.0, steps=N_POINTS)
y = a * X + b + torch.randn(N_POINTS) * noise

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(X.cpu(),y.cpu(),label='ground truth', marker='.')
ax.grid()
plt.show()

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 30px; color: black; font-weight: bold;">
# 1 : learnable parameters for MLE
# </div>

# %% [markdown]
# Dans Pyro, il faut voir la fonction "model" comme une déclaration du modèle génératif, pas comme une fonction au sens Python.
#
# - `def model(X, y=None)` définit $p_{\theta}(x \vert z)p(z)$
#
# Primitives:
# - `pyro.param(name, dist, *args)`
#   - les Torch.tensor wrapped dans `pyro.param` deviennent des learnable parameters (wrt Optimizer)
#   - les Torch.tensor dans `pyro.param` sont stockés dans le global Pyro Parameter Store (`pyro.get_param_store()`)
#   - à l'initialisation `pyro.param(name, initial_value, ...)` : si name existe déjà, la valeur actuelle est retournée. Sinon, name est créé dans le Store et la valeur stockée.
#   - on peut imposer des contraintes : `constraint=constraints.positive` par exemple (typiquement pour des variances/écart-types)
#   - usage typique : utilisation dans le model, à l'exclusion des `pyro.sample`, pour faire du MLE
#   - autre usage : paramètres dans l'approximate posterior ("guide") pour la variational inférence (SVI)
#
#
# - `pyro.sample(name, dist, *args)`
#   - the core declarative statement of a Random Variable in Pyro
#   - creates a stochastic *site* (ie RV), ie declares the `name` as a random variable from the `dist`
#   - `name` is mandatory and unique. Allows Pyro's inference algorythms (SVI...) and handlers (`trace`, `replay`,...) to track, manipulate, condition on that variable.
#   - **the behavior of `pyro.sample` changes based on the context** (ie which handlers or algorithms are running it):
#     - context `model` with no `obs` : draws a random value from the distribution (=> generates a prior sample or a prediction $\hat{y}$)
#     - context `model` with `obs`: does not draw a sample. Returns the observation $y$ and compute the log prob $\log{p(y)}$ (=> defines the likelihood term for the ELBO calculation)
#     - context *guide* (ie $q_{\phi}(z \vert x)$) : draws a random value from the *guide* (ie approximate posterior) (=> generate $z \sim q_{\phi}(z \vert x)$ for the gradient of ELBO calculation). (So `pyro.sample` in a *guide* never takes an `obs` argument.)
#     - context trace : records the resulting random value and log-prob in the trace object (=> enables advanced handling like `replay`)
#   - the parameters of the distribution inside `pyro.sample` can be learnable `pyro.param`
#
#
# - `def model(X, y=None)`
#   - Training, ELBO calculation : `y is not None`: priors are sampled (if any), the log-likelihood is computed in `pyro.sample("obs", dist, obs=y)`. The `model(X,y)` returns $\hat{y}$ which is either the log-likelihood or the observation itself, depending on the handlers.
#   - Prediction, sampling : `y=None` : when `model` is called outside the SVI training loop.
#     - if `model` is not under a `replay` : it uses samples from the priors
#     - if `model` is under `replay` : it uses values sampled from the *guide* (approximate posterior)
#     - `pyro.sample("obs",...,obs=None)` is executed : a random sample is drawn from the likelihood distribution.

# %%
# Simple Bayesian linear regression model

def model(X, y=None):
    
    # inputs: ----------------------
    #   X : torch.tensor(size,1)
    #   y : torch.tensor(size,1) if provided
    
    # learnable parameters ------------------------
    param_a = pyro.param("param_a", torch.tensor((0.)))
    param_b = pyro.param("param_b", torch.tensor((0.)))
    param_noise = pyro.param("param_noise", torch.tensor((1.0)), constraint=constraints.positive)
    
    # priors ---------------------------------
    # No prior here, we run a simple parameter MLE
    
    # gaussian likelihood ----------------------------
    means = X * param_a + param_b
    with pyro.plate("data", len(X)):
        y_hat = pyro.sample("obs", dist.Normal(means, param_noise), obs=y)
    
    # return is optional :
    #   - If y is None, this is a sample (tensor)
    #   - If y is given, this is the log likelihood
    return y_hat

# %%
# log likelihood
print(model(X,y))
# Out:
# tensor([-1.1065, -0.9142, -0.9730, -1.1636, -0.8937, -0.9351, -0.7933, -0.8060,
#         -0.7527, -0.8505, -0.8117, -0.8773, -0.8610, -0.7495, -0.6918, -0.5552,
#         -0.6841, -0.7002, -0.6505, -0.7062, -0.5202, -0.5019, -0.5981, -0.4314,
#         -0.3934, -0.4288, -0.3410, -0.3599, -0.2660, -0.4556, -0.3039, -0.2232,
#         -0.3653, -0.4041, -0.3237, -0.1636, -0.5391, -0.2982, -0.1496, -0.3222,
#         -0.1583, -0.2488, -0.0616,  0.0086, -0.0600, -0.1940,  0.1765,  0.0135,
#         -0.0023, -0.0699, -0.0875,  0.1718,  0.0867,  0.1482,  0.3560,  0.0040,
#          0.1500,  0.2890,  0.1905,  0.1366,  0.3798,  0.3087,  0.3991,  0.1758,
#          0.3157,  0.3406,  0.3552,  0.4159,  0.3294,  0.3896,  0.4953,  0.5273,
#          0.4697,  0.3589,  0.6062,  0.5740,  0.5661,  0.6340,  0.7298,  0.8325,
#          0.3723,  0.5397,  0.7398,  0.7299,  0.6460,  0.5350,  0.5469,  0.6433,
#          0.7964,  0.8649,  0.9504,  0.6557,  0.9397,  0.7839,  0.8378,  1.0124,
#          1.0446,  0.9413,  1.0997,  1.1561], device='cuda:0')

# %%
# sample y
y_hat = model(X)
print(y_hat)
# Out:
# tensor([-0.1396,  1.1201, -0.9687, -1.4035,  0.9009,  0.0360,  0.5138, -0.8446,
#         -0.5944, -1.7969, -1.5545,  0.2540,  0.0355, -0.1405,  0.6635, -0.2890,
#          0.8609, -0.3380,  0.2867, -0.5954, -0.7647, -1.3143, -0.0723,  1.0243,
#          0.6479,  0.0589, -1.1175,  0.3405,  0.2944,  1.2173,  0.5587,  0.6082,
#         -1.0731, -0.4007, -0.7281,  1.2151, -0.3245,  0.4469, -2.0824, -2.2712,
#         -0.7261, -0.7163,  1.3726,  1.1312,  0.5385, -1.0330,  0.0326,  0.8202,
#          0.4043,  0.3990, -1.3067, -2.2127,  0.3063,  0.7214, -1.4468, -0.3149,
#         -0.0056,  1.0700,  1.2853, -0.9406,  1.1340,  0.1354, -0.5538,  0.1476,
#          1.6843, -0.4912, -0.1011,  0.2854,  0.0468, -0.9182, -0.2147, -0.7092,
#         -0.6974, -2.4834, -0.2631,  1.2537,  0.5896, -1.1006,  0.9309, -0.3132,
#         -0.8844,  1.1183, -0.5025,  0.7343,  0.0518,  2.3223, -0.1250,  0.8421,
#         -1.3814, -1.3875,  0.2708,  1.6739,  0.5740,  0.7195, -2.2390,  1.8583,
#         -0.5346,  1.2089, -1.6152, -0.8873], device='cuda:0',
#        grad_fn=<AddBackward0>)

# %% [markdown]
# Stochastic Variational Inference framework
#
# Here, we do not use a *guide* (ie an approximate posterior) as we are just looking for a MLE of the parameters.
#
# `pyro.infer.SVI` is the main class for Stochastic Variational Inference in Pyro.
#
# - arguments:
#   - `model` : the probabilistic model that defines the joint distribution $p_{\theta}(x,z) = p_{\theta}(x \vert z)p(z)$ that defines the priors and the likelihood. Can use parameters.
#   - `guide` : this is the approximate posterior $q_{\phi}(z)$, defines the parametric family used for the approximate posterior.
#   - `optim`: optim algorithm, typically Adam, handles gradient steps.
#   - `loss` : the objective function to be minimzed. Typically `Trace_ELBO` (which reduces to log-likelihood below as there is no approximate posterior).
#     - `Trace_ELBO` has a `num_particles` argument that defines the number of samples used for the estimation of the expectation in the ELBO calculation (impacts the variance of the estimate and the computation load)
#
# - `svi.step()` : uses `guide` and `model` to compute the ELBO, stores the gradient in the the Pyro Store,  perform a gradient step, return the scalar value of the loss.
#
# - `svi.evaluate_loss()` : compute and return the loss, does not compute nor apply gradients.

# %%
# to learn the parameters, we implement a SVI without an approximate posterior
def q_phi(X,y=None):
    pass

# optimizer - using the Pyro wrapper for Adam
optimizer = Adam(
    {"lr": 1e-2}
)

# instantiate the SVI engine
svi = SVI(
    model=model,
    guide=q_phi,
    optim=optimizer,
    loss=Trace_ELBO()
)

# %%
# Clear old parameters
pyro.clear_param_store() 

# training parameters
n_epochs = 1000
training_losses = []
validation_losses = []

for step in range(n_epochs):
    # perform the training : compute and backprop gradients
    loss = svi.step(X,y)
    # perform evaluation only
    eval_loss = svi.evaluate_loss(X,y)
    # log the results
    training_losses.append(loss)
    validation_losses.append(eval_loss)
    # get the parameters
    est_a = pyro.param("param_a")
    est_b = pyro.param("param_b")
    est_noise = pyro.param("param_noise")
    # report out
    print(f'Epoch {step+1:<6} / {n_epochs:<6} - loss = {loss:.3e} - val loss = {eval_loss:.3e} -- est. : param_a = {est_a:.3e}, param_b = {est_b:.3e}, param_noise = {est_noise:.3e}')
# Out:
# Epoch 1      / 1000   - loss = 1.097e+02 - val loss = 1.089e+02 -- est. : param_a = 1.000e-02, param_b = 1.000e-02, param_noise = 9.900e-01
# Epoch 2      / 1000   - loss = 1.089e+02 - val loss = 1.081e+02 -- est. : param_a = 1.999e-02, param_b = 1.838e-02, param_noise = 9.802e-01
# Epoch 3      / 1000   - loss = 1.081e+02 - val loss = 1.073e+02 -- est. : param_a = 2.997e-02, param_b = 2.198e-02, param_noise = 9.705e-01
# Epoch 4      / 1000   - loss = 1.073e+02 - val loss = 1.065e+02 -- est. : param_a = 3.994e-02, param_b = 2.070e-02, param_noise = 9.608e-01
# Epoch 5      / 1000   - loss = 1.065e+02 - val loss = 1.057e+02 -- est. : param_a = 4.991e-02, param_b = 1.651e-02, param_noise = 9.513e-01
# Epoch 6      / 1000   - loss = 1.057e+02 - val loss = 1.049e+02 -- est. : param_a = 5.988e-02, param_b = 1.064e-02, param_noise = 9.418e-01
# Epoch 7      / 1000   - loss = 1.049e+02 - val loss = 1.040e+02 -- est. : param_a = 6.985e-02, param_b = 3.736e-03, param_noise = 9.325e-01
# Epoch 8      / 1000   - loss = 1.040e+02 - val loss = 1.032e+02 -- est. : param_a = 7.985e-02, param_b = -3.820e-03, param_noise = 9.232e-01
# Epoch 9      / 1000   - loss = 1.032e+02 - val loss = 1.024e+02 -- est. : param_a = 8.988e-02, param_b = -1.177e-02, param_noise = 9.141e-01
# Epoch 10     / 1000   - loss = 1.024e+02 - val loss = 1.016e+02 -- est. : param_a = 9.993e-02, param_b = -1.989e-02, param_noise = 9.050e-01
# Epoch 11     / 1000   - loss = 1.016e+02 - val loss = 1.008e+02 -- est. : param_a = 1.100e-01, param_b = -2.799e-02, param_noise = 8.961e-01
# Epoch 12     / 1000   - loss = 1.008e+02 - val loss = 1.000e+02 -- est. : param_a = 1.201e-01, param_b = -3.588e-02, param_noise = 8.872e-01
# Epoch 13     / 1000   - loss = 1.000e+02 - val loss = 9.920e+01 -- est. : param_a = 1.303e-01, param_b = -4.337e-02, param_noise = 8.785e-01
# Epoch 14     / 1000   - loss = 9.920e+01 - val loss = 9.840e+01 -- est. : param_a = 1.405e-01, param_b = -5.029e-02, param_noise = 8.698e-01
# Epoch 15     / 1000   - loss = 9.840e+01 - val loss = 9.760e+01 -- est. : param_a = 1.508e-01, param_b = -5.653e-02, param_noise = 8.613e-01
# Epoch 16     / 1000   - loss = 9.760e+01 - val loss = 9.680e+01 -- est. : param_a = 1.611e-01, param_b = -6.203e-02, param_noise = 8.528e-01
# Epoch 17     / 1000   - loss = 9.680e+01 - val loss = 9.601e+01 -- est. : param_a = 1.715e-01, param_b = -6.683e-02, param_noise = 8.445e-01
# Epoch 18     / 1000   - loss = 9.601e+01 - val loss = 9.521e+01 -- est. : param_a = 1.819e-01, param_b = -7.104e-02, param_noise = 8.362e-01
# Epoch 19     / 1000   - loss = 9.521e+01 - val loss = 9.441e+01 -- est. : param_a = 1.924e-01, param_b = -7.482e-02, param_noise = 8.280e-01
# Epoch 20     / 1000   - loss = 9.441e+01 - val loss = 9.361e+01 -- est. : param_a = 2.029e-01, param_b = -7.840e-02, param_noise = 8.200e-01
# Epoch 21     / 1000   - loss = 9.361e+01 - val loss = 9.282e+01 -- est. : param_a = 2.134e-01, param_b = -8.200e-02, param_noise = 8.120e-01
# Epoch 22     / 1000   - loss = 9.282e+01 - val loss = 9.202e+01 -- est. : param_a = 2.240e-01, param_b = -8.583e-02, param_noise = 8.041e-01
# Epoch 23     / 1000   - loss = 9.202e+01 - val loss = 9.123e+01 -- est. : param_a = 2.346e-01, param_b = -9.006e-02, param_noise = 7.963e-01
# Epoch 24     / 1000   - loss = 9.123e+01 - val loss = 9.043e+01 -- est. : param_a = 2.452e-01, param_b = -9.479e-02, param_noise = 7.886e-01
# Epoch 25     / 1000   - loss = 9.043e+01 - val loss = 8.964e+01 -- est. : param_a = 2.559e-01, param_b = -1.000e-01, param_noise = 7.810e-01
# Epoch 26     / 1000   - loss = 8.964e+01 - val loss = 8.884e+01 -- est. : param_a = 2.666e-01, param_b = -1.058e-01, param_noise = 7.735e-01
# Epoch 27     / 1000   - loss = 8.884e+01 - val loss = 8.804e+01 -- est. : param_a = 2.774e-01, param_b = -1.120e-01, param_noise = 7.661e-01
# Epoch 28     / 1000   - loss = 8.804e+01 - val loss = 8.725e+01 -- est. : param_a = 2.881e-01, param_b = -1.184e-01, param_noise = 7.588e-01
# Epoch 29     / 1000   - loss = 8.725e+01 - val loss = 8.645e+01 -- est. : param_a = 2.990e-01, param_b = -1.250e-01, param_noise = 7.515e-01
# Epoch 30     / 1000   - loss = 8.645e+01 - val loss = 8.566e+01 -- est. : param_a = 3.099e-01, param_b = -1.316e-01, param_noise = 7.444e-01
# Epoch 31     / 1000   - loss = 8.566e+01 - val loss = 8.486e+01 -- est. : param_a = 3.208e-01, param_b = -1.381e-01, param_noise = 7.373e-01
# Epoch 32     / 1000   - loss = 8.486e+01 - val loss = 8.406e+01 -- est. : param_a = 3.318e-01, param_b = -1.443e-01, param_noise = 7.303e-01
# Epoch 33     / 1000   - loss = 8.406e+01 - val loss = 8.326e+01 -- est. : param_a = 3.429e-01, param_b = -1.502e-01, param_noise = 7.234e-01
# Epoch 34     / 1000   - loss = 8.326e+01 - val loss = 8.246e+01 -- est. : param_a = 3.540e-01, param_b = -1.557e-01, param_noise = 7.166e-01
# Epoch 35     / 1000   - loss = 8.246e+01 - val loss = 8.166e+01 -- est. : param_a = 3.652e-01, param_b = -1.609e-01, param_noise = 7.099e-01
# Epoch 36     / 1000   - loss = 8.166e+01 - val loss = 8.086e+01 -- est. : param_a = 3.764e-01, param_b = -1.659e-01, param_noise = 7.032e-01
# Epoch 37     / 1000   - loss = 8.086e+01 - val loss = 8.006e+01 -- est. : param_a = 3.877e-01, param_b = -1.708e-01, param_noise = 6.966e-01
# Epoch 38     / 1000   - loss = 8.006e+01 - val loss = 7.926e+01 -- est. : param_a = 3.990e-01, param_b = -1.758e-01, param_noise = 6.902e-01
# Epoch 39     / 1000   - loss = 7.926e+01 - val loss = 7.845e+01 -- est. : param_a = 4.103e-01, param_b = -1.810e-01, param_noise = 6.837e-01
# Epoch 40     / 1000   - loss = 7.845e+01 - val loss = 7.764e+01 -- est. : param_a = 4.218e-01, param_b = -1.864e-01, param_noise = 6.774e-01
# Epoch 41     / 1000   - loss = 7.764e+01 - val loss = 7.684e+01 -- est. : param_a = 4.332e-01, param_b = -1.922e-01, param_noise = 6.711e-01
# Epoch 42     / 1000   - loss = 7.684e+01 - val loss = 7.602e+01 -- est. : param_a = 4.447e-01, param_b = -1.982e-01, param_noise = 6.649e-01
# Epoch 43     / 1000   - loss = 7.602e+01 - val loss = 7.521e+01 -- est. : param_a = 4.562e-01, param_b = -2.045e-01, param_noise = 6.588e-01
# Epoch 44     / 1000   - loss = 7.521e+01 - val loss = 7.440e+01 -- est. : param_a = 4.678e-01, param_b = -2.109e-01, param_noise = 6.528e-01
# Epoch 45     / 1000   - loss = 7.440e+01 - val loss = 7.358e+01 -- est. : param_a = 4.795e-01, param_b = -2.173e-01, param_noise = 6.468e-01
# Epoch 46     / 1000   - loss = 7.358e+01 - val loss = 7.276e+01 -- est. : param_a = 4.912e-01, param_b = -2.236e-01, param_noise = 6.409e-01
# Epoch 47     / 1000   - loss = 7.276e+01 - val loss = 7.194e+01 -- est. : param_a = 5.029e-01, param_b = -2.298e-01, param_noise = 6.350e-01
# Epoch 48     / 1000   - loss = 7.194e+01 - val loss = 7.111e+01 -- est. : param_a = 5.147e-01, param_b = -2.357e-01, param_noise = 6.293e-01
# Epoch 49     / 1000   - loss = 7.111e+01 - val loss = 7.028e+01 -- est. : param_a = 5.265e-01, param_b = -2.414e-01, param_noise = 6.236e-01
# Epoch 50     / 1000   - loss = 7.028e+01 - val loss = 6.945e+01 -- est. : param_a = 5.384e-01, param_b = -2.470e-01, param_noise = 6.179e-01
# Epoch 51     / 1000   - loss = 6.945e+01 - val loss = 6.862e+01 -- est. : param_a = 5.503e-01, param_b = -2.526e-01, param_noise = 6.123e-01
# Epoch 52     / 1000   - loss = 6.862e+01 - val loss = 6.778e+01 -- est. : param_a = 5.623e-01, param_b = -2.583e-01, param_noise = 6.068e-01
# Epoch 53     / 1000   - loss = 6.778e+01 - val loss = 6.694e+01 -- est. : param_a = 5.743e-01, param_b = -2.641e-01, param_noise = 6.013e-01
# Epoch 54     / 1000   - loss = 6.694e+01 - val loss = 6.609e+01 -- est. : param_a = 5.864e-01, param_b = -2.702e-01, param_noise = 5.959e-01
# Epoch 55     / 1000   - loss = 6.609e+01 - val loss = 6.524e+01 -- est. : param_a = 5.984e-01, param_b = -2.764e-01, param_noise = 5.906e-01
# Epoch 56     / 1000   - loss = 6.524e+01 - val loss = 6.439e+01 -- est. : param_a = 6.106e-01, param_b = -2.828e-01, param_noise = 5.853e-01
# Epoch 57     / 1000   - loss = 6.439e+01 - val loss = 6.353e+01 -- est. : param_a = 6.227e-01, param_b = -2.893e-01, param_noise = 5.800e-01
# Epoch 58     / 1000   - loss = 6.353e+01 - val loss = 6.267e+01 -- est. : param_a = 6.349e-01, param_b = -2.957e-01, param_noise = 5.749e-01
# Epoch 59     / 1000   - loss = 6.267e+01 - val loss = 6.181e+01 -- est. : param_a = 6.472e-01, param_b = -3.019e-01, param_noise = 5.697e-01
# Epoch 60     / 1000   - loss = 6.181e+01 - val loss = 6.094e+01 -- est. : param_a = 6.595e-01, param_b = -3.081e-01, param_noise = 5.646e-01
# Epoch 61     / 1000   - loss = 6.094e+01 - val loss = 6.007e+01 -- est. : param_a = 6.718e-01, param_b = -3.141e-01, param_noise = 5.596e-01
# Epoch 62     / 1000   - loss = 6.007e+01 - val loss = 5.919e+01 -- est. : param_a = 6.842e-01, param_b = -3.201e-01, param_noise = 5.546e-01
# Epoch 63     / 1000   - loss = 5.919e+01 - val loss = 5.831e+01 -- est. : param_a = 6.966e-01, param_b = -3.261e-01, param_noise = 5.497e-01
# Epoch 64     / 1000   - loss = 5.831e+01 - val loss = 5.742e+01 -- est. : param_a = 7.090e-01, param_b = -3.322e-01, param_noise = 5.448e-01
# Epoch 65     / 1000   - loss = 5.742e+01 - val loss = 5.653e+01 -- est. : param_a = 7.215e-01, param_b = -3.385e-01, param_noise = 5.399e-01
# Epoch 66     / 1000   - loss = 5.653e+01 - val loss = 5.563e+01 -- est. : param_a = 7.340e-01, param_b = -3.449e-01, param_noise = 5.351e-01
# Epoch 67     / 1000   - loss = 5.563e+01 - val loss = 5.472e+01 -- est. : param_a = 7.465e-01, param_b = -3.513e-01, param_noise = 5.303e-01
# Epoch 68     / 1000   - loss = 5.472e+01 - val loss = 5.382e+01 -- est. : param_a = 7.591e-01, param_b = -3.578e-01, param_noise = 5.256e-01
# Epoch 69     / 1000   - loss = 5.382e+01 - val loss = 5.290e+01 -- est. : param_a = 7.717e-01, param_b = -3.643e-01, param_noise = 5.209e-01
# Epoch 70     / 1000   - loss = 5.290e+01 - val loss = 5.198e+01 -- est. : param_a = 7.843e-01, param_b = -3.706e-01, param_noise = 5.163e-01
# Epoch 71     / 1000   - loss = 5.198e+01 - val loss = 5.106e+01 -- est. : param_a = 7.969e-01, param_b = -3.769e-01, param_noise = 5.117e-01
# Epoch 72     / 1000   - loss = 5.106e+01 - val loss = 5.013e+01 -- est. : param_a = 8.096e-01, param_b = -3.831e-01, param_noise = 5.071e-01
# Epoch 73     / 1000   - loss = 5.013e+01 - val loss = 4.919e+01 -- est. : param_a = 8.223e-01, param_b = -3.894e-01, param_noise = 5.026e-01
# Epoch 74     / 1000   - loss = 4.919e+01 - val loss = 4.825e+01 -- est. : param_a = 8.351e-01, param_b = -3.957e-01, param_noise = 4.981e-01
# Epoch 75     / 1000   - loss = 4.825e+01 - val loss = 4.730e+01 -- est. : param_a = 8.478e-01, param_b = -4.021e-01, param_noise = 4.936e-01
# Epoch 76     / 1000   - loss = 4.730e+01 - val loss = 4.634e+01 -- est. : param_a = 8.606e-01, param_b = -4.086e-01, param_noise = 4.892e-01
# Epoch 77     / 1000   - loss = 4.634e+01 - val loss = 4.538e+01 -- est. : param_a = 8.735e-01, param_b = -4.152e-01, param_noise = 4.848e-01
# Epoch 78     / 1000   - loss = 4.538e+01 - val loss = 4.441e+01 -- est. : param_a = 8.863e-01, param_b = -4.217e-01, param_noise = 4.804e-01
# Epoch 79     / 1000   - loss = 4.441e+01 - val loss = 4.344e+01 -- est. : param_a = 8.992e-01, param_b = -4.282e-01, param_noise = 4.761e-01
# Epoch 80     / 1000   - loss = 4.344e+01 - val loss = 4.245e+01 -- est. : param_a = 9.120e-01, param_b = -4.346e-01, param_noise = 4.718e-01
# Epoch 81     / 1000   - loss = 4.245e+01 - val loss = 4.146e+01 -- est. : param_a = 9.249e-01, param_b = -4.410e-01, param_noise = 4.675e-01
# Epoch 82     / 1000   - loss = 4.146e+01 - val loss = 4.047e+01 -- est. : param_a = 9.379e-01, param_b = -4.474e-01, param_noise = 4.633e-01
# Epoch 83     / 1000   - loss = 4.047e+01 - val loss = 3.947e+01 -- est. : param_a = 9.508e-01, param_b = -4.539e-01, param_noise = 4.591e-01
# Epoch 84     / 1000   - loss = 3.947e+01 - val loss = 3.846e+01 -- est. : param_a = 9.638e-01, param_b = -4.604e-01, param_noise = 4.549e-01
# Epoch 85     / 1000   - loss = 3.846e+01 - val loss = 3.744e+01 -- est. : param_a = 9.768e-01, param_b = -4.670e-01, param_noise = 4.507e-01
# Epoch 86     / 1000   - loss = 3.744e+01 - val loss = 3.642e+01 -- est. : param_a = 9.898e-01, param_b = -4.736e-01, param_noise = 4.466e-01
# Epoch 87     / 1000   - loss = 3.642e+01 - val loss = 3.539e+01 -- est. : param_a = 1.003e+00, param_b = -4.802e-01, param_noise = 4.425e-01
# Epoch 88     / 1000   - loss = 3.539e+01 - val loss = 3.435e+01 -- est. : param_a = 1.016e+00, param_b = -4.867e-01, param_noise = 4.384e-01
# Epoch 89     / 1000   - loss = 3.435e+01 - val loss = 3.330e+01 -- est. : param_a = 1.029e+00, param_b = -4.932e-01, param_noise = 4.343e-01
# Epoch 90     / 1000   - loss = 3.330e+01 - val loss = 3.225e+01 -- est. : param_a = 1.042e+00, param_b = -4.997e-01, param_noise = 4.303e-01
# Epoch 91     / 1000   - loss = 3.225e+01 - val loss = 3.119e+01 -- est. : param_a = 1.055e+00, param_b = -5.062e-01, param_noise = 4.263e-01
# Epoch 92     / 1000   - loss = 3.119e+01 - val loss = 3.012e+01 -- est. : param_a = 1.068e+00, param_b = -5.128e-01, param_noise = 4.223e-01
# Epoch 93     / 1000   - loss = 3.012e+01 - val loss = 2.904e+01 -- est. : param_a = 1.081e+00, param_b = -5.194e-01, param_noise = 4.183e-01
# Epoch 94     / 1000   - loss = 2.904e+01 - val loss = 2.795e+01 -- est. : param_a = 1.094e+00, param_b = -5.261e-01, param_noise = 4.143e-01
# Epoch 95     / 1000   - loss = 2.795e+01 - val loss = 2.686e+01 -- est. : param_a = 1.107e+00, param_b = -5.327e-01, param_noise = 4.104e-01
# Epoch 96     / 1000   - loss = 2.686e+01 - val loss = 2.576e+01 -- est. : param_a = 1.121e+00, param_b = -5.392e-01, param_noise = 4.065e-01
# Epoch 97     / 1000   - loss = 2.576e+01 - val loss = 2.465e+01 -- est. : param_a = 1.134e+00, param_b = -5.458e-01, param_noise = 4.026e-01
# Epoch 98     / 1000   - loss = 2.465e+01 - val loss = 2.353e+01 -- est. : param_a = 1.147e+00, param_b = -5.523e-01, param_noise = 3.988e-01
# Epoch 99     / 1000   - loss = 2.353e+01 - val loss = 2.241e+01 -- est. : param_a = 1.160e+00, param_b = -5.589e-01, param_noise = 3.949e-01
# Epoch 100    / 1000   - loss = 2.241e+01 - val loss = 2.128e+01 -- est. : param_a = 1.173e+00, param_b = -5.656e-01, param_noise = 3.911e-01
# Epoch 101    / 1000   - loss = 2.128e+01 - val loss = 2.014e+01 -- est. : param_a = 1.186e+00, param_b = -5.722e-01, param_noise = 3.873e-01
# Epoch 102    / 1000   - loss = 2.014e+01 - val loss = 1.899e+01 -- est. : param_a = 1.200e+00, param_b = -5.788e-01, param_noise = 3.835e-01
# Epoch 103    / 1000   - loss = 1.899e+01 - val loss = 1.783e+01 -- est. : param_a = 1.213e+00, param_b = -5.854e-01, param_noise = 3.797e-01
# Epoch 104    / 1000   - loss = 1.783e+01 - val loss = 1.666e+01 -- est. : param_a = 1.226e+00, param_b = -5.920e-01, param_noise = 3.760e-01
# Epoch 105    / 1000   - loss = 1.666e+01 - val loss = 1.549e+01 -- est. : param_a = 1.239e+00, param_b = -5.986e-01, param_noise = 3.723e-01
# Epoch 106    / 1000   - loss = 1.549e+01 - val loss = 1.431e+01 -- est. : param_a = 1.252e+00, param_b = -6.052e-01, param_noise = 3.686e-01
# Epoch 107    / 1000   - loss = 1.431e+01 - val loss = 1.312e+01 -- est. : param_a = 1.266e+00, param_b = -6.118e-01, param_noise = 3.649e-01
# Epoch 108    / 1000   - loss = 1.312e+01 - val loss = 1.192e+01 -- est. : param_a = 1.279e+00, param_b = -6.185e-01, param_noise = 3.612e-01
# Epoch 109    / 1000   - loss = 1.192e+01 - val loss = 1.071e+01 -- est. : param_a = 1.292e+00, param_b = -6.251e-01, param_noise = 3.576e-01
# Epoch 110    / 1000   - loss = 1.071e+01 - val loss = 9.498e+00 -- est. : param_a = 1.305e+00, param_b = -6.316e-01, param_noise = 3.539e-01
# Epoch 111    / 1000   - loss = 9.498e+00 - val loss = 8.275e+00 -- est. : param_a = 1.318e+00, param_b = -6.382e-01, param_noise = 3.503e-01
# Epoch 112    / 1000   - loss = 8.275e+00 - val loss = 7.046e+00 -- est. : param_a = 1.331e+00, param_b = -6.448e-01, param_noise = 3.467e-01
# Epoch 113    / 1000   - loss = 7.046e+00 - val loss = 5.808e+00 -- est. : param_a = 1.345e+00, param_b = -6.514e-01, param_noise = 3.431e-01
# Epoch 114    / 1000   - loss = 5.808e+00 - val loss = 4.563e+00 -- est. : param_a = 1.358e+00, param_b = -6.580e-01, param_noise = 3.396e-01
# Epoch 115    / 1000   - loss = 4.563e+00 - val loss = 3.310e+00 -- est. : param_a = 1.371e+00, param_b = -6.646e-01, param_noise = 3.360e-01
# Epoch 116    / 1000   - loss = 3.310e+00 - val loss = 2.050e+00 -- est. : param_a = 1.384e+00, param_b = -6.711e-01, param_noise = 3.325e-01
# Epoch 117    / 1000   - loss = 2.050e+00 - val loss = 7.834e-01 -- est. : param_a = 1.397e+00, param_b = -6.777e-01, param_noise = 3.290e-01
# Epoch 118    / 1000   - loss = 7.834e-01 - val loss = -4.905e-01 -- est. : param_a = 1.410e+00, param_b = -6.843e-01, param_noise = 3.255e-01
# Epoch 119    / 1000   - loss = -4.905e-01 - val loss = -1.771e+00 -- est. : param_a = 1.423e+00, param_b = -6.908e-01, param_noise = 3.221e-01
# Epoch 120    / 1000   - loss = -1.771e+00 - val loss = -3.058e+00 -- est. : param_a = 1.436e+00, param_b = -6.973e-01, param_noise = 3.186e-01
# Epoch 121    / 1000   - loss = -3.058e+00 - val loss = -4.352e+00 -- est. : param_a = 1.449e+00, param_b = -7.038e-01, param_noise = 3.152e-01
# Epoch 122    / 1000   - loss = -4.352e+00 - val loss = -5.652e+00 -- est. : param_a = 1.462e+00, param_b = -7.103e-01, param_noise = 3.118e-01
# Epoch 123    / 1000   - loss = -5.652e+00 - val loss = -6.957e+00 -- est. : param_a = 1.475e+00, param_b = -7.168e-01, param_noise = 3.084e-01
# Epoch 124    / 1000   - loss = -6.957e+00 - val loss = -8.267e+00 -- est. : param_a = 1.488e+00, param_b = -7.233e-01, param_noise = 3.050e-01
# Epoch 125    / 1000   - loss = -8.267e+00 - val loss = -9.583e+00 -- est. : param_a = 1.501e+00, param_b = -7.298e-01, param_noise = 3.017e-01
# Epoch 126    / 1000   - loss = -9.583e+00 - val loss = -1.090e+01 -- est. : param_a = 1.514e+00, param_b = -7.362e-01, param_noise = 2.983e-01
# Epoch 127    / 1000   - loss = -1.090e+01 - val loss = -1.223e+01 -- est. : param_a = 1.527e+00, param_b = -7.426e-01, param_noise = 2.950e-01
# Epoch 128    / 1000   - loss = -1.223e+01 - val loss = -1.356e+01 -- est. : param_a = 1.539e+00, param_b = -7.490e-01, param_noise = 2.917e-01
# Epoch 129    / 1000   - loss = -1.356e+01 - val loss = -1.489e+01 -- est. : param_a = 1.552e+00, param_b = -7.554e-01, param_noise = 2.885e-01
# Epoch 130    / 1000   - loss = -1.489e+01 - val loss = -1.622e+01 -- est. : param_a = 1.565e+00, param_b = -7.618e-01, param_noise = 2.852e-01
# Epoch 131    / 1000   - loss = -1.622e+01 - val loss = -1.756e+01 -- est. : param_a = 1.577e+00, param_b = -7.681e-01, param_noise = 2.820e-01
# Epoch 132    / 1000   - loss = -1.756e+01 - val loss = -1.890e+01 -- est. : param_a = 1.590e+00, param_b = -7.744e-01, param_noise = 2.788e-01
# Epoch 133    / 1000   - loss = -1.890e+01 - val loss = -2.024e+01 -- est. : param_a = 1.603e+00, param_b = -7.807e-01, param_noise = 2.756e-01
# Epoch 134    / 1000   - loss = -2.024e+01 - val loss = -2.158e+01 -- est. : param_a = 1.615e+00, param_b = -7.869e-01, param_noise = 2.725e-01
# Epoch 135    / 1000   - loss = -2.158e+01 - val loss = -2.293e+01 -- est. : param_a = 1.627e+00, param_b = -7.931e-01, param_noise = 2.693e-01
# Epoch 136    / 1000   - loss = -2.293e+01 - val loss = -2.427e+01 -- est. : param_a = 1.640e+00, param_b = -7.993e-01, param_noise = 2.662e-01
# Epoch 137    / 1000   - loss = -2.427e+01 - val loss = -2.561e+01 -- est. : param_a = 1.652e+00, param_b = -8.055e-01, param_noise = 2.631e-01
# Epoch 138    / 1000   - loss = -2.561e+01 - val loss = -2.695e+01 -- est. : param_a = 1.664e+00, param_b = -8.116e-01, param_noise = 2.600e-01
# Epoch 139    / 1000   - loss = -2.695e+01 - val loss = -2.828e+01 -- est. : param_a = 1.676e+00, param_b = -8.176e-01, param_noise = 2.570e-01
# Epoch 140    / 1000   - loss = -2.828e+01 - val loss = -2.961e+01 -- est. : param_a = 1.688e+00, param_b = -8.237e-01, param_noise = 2.540e-01
# Epoch 141    / 1000   - loss = -2.961e+01 - val loss = -3.094e+01 -- est. : param_a = 1.700e+00, param_b = -8.296e-01, param_noise = 2.510e-01
# Epoch 142    / 1000   - loss = -3.094e+01 - val loss = -3.226e+01 -- est. : param_a = 1.712e+00, param_b = -8.356e-01, param_noise = 2.480e-01
# Epoch 143    / 1000   - loss = -3.226e+01 - val loss = -3.358e+01 -- est. : param_a = 1.724e+00, param_b = -8.414e-01, param_noise = 2.451e-01
# Epoch 144    / 1000   - loss = -3.358e+01 - val loss = -3.489e+01 -- est. : param_a = 1.735e+00, param_b = -8.472e-01, param_noise = 2.422e-01
# Epoch 145    / 1000   - loss = -3.489e+01 - val loss = -3.619e+01 -- est. : param_a = 1.747e+00, param_b = -8.530e-01, param_noise = 2.393e-01
# Epoch 146    / 1000   - loss = -3.619e+01 - val loss = -3.748e+01 -- est. : param_a = 1.758e+00, param_b = -8.587e-01, param_noise = 2.364e-01
# Epoch 147    / 1000   - loss = -3.748e+01 - val loss = -3.877e+01 -- est. : param_a = 1.770e+00, param_b = -8.643e-01, param_noise = 2.336e-01
# Epoch 148    / 1000   - loss = -3.877e+01 - val loss = -4.004e+01 -- est. : param_a = 1.781e+00, param_b = -8.699e-01, param_noise = 2.308e-01
# Epoch 149    / 1000   - loss = -4.004e+01 - val loss = -4.130e+01 -- est. : param_a = 1.792e+00, param_b = -8.754e-01, param_noise = 2.280e-01
# Epoch 150    / 1000   - loss = -4.130e+01 - val loss = -4.255e+01 -- est. : param_a = 1.802e+00, param_b = -8.808e-01, param_noise = 2.253e-01
# Epoch 151    / 1000   - loss = -4.255e+01 - val loss = -4.378e+01 -- est. : param_a = 1.813e+00, param_b = -8.862e-01, param_noise = 2.225e-01
# Epoch 152    / 1000   - loss = -4.378e+01 - val loss = -4.500e+01 -- est. : param_a = 1.824e+00, param_b = -8.915e-01, param_noise = 2.198e-01
# Epoch 153    / 1000   - loss = -4.500e+01 - val loss = -4.621e+01 -- est. : param_a = 1.834e+00, param_b = -8.966e-01, param_noise = 2.172e-01
# Epoch 154    / 1000   - loss = -4.621e+01 - val loss = -4.739e+01 -- est. : param_a = 1.844e+00, param_b = -9.017e-01, param_noise = 2.146e-01
# Epoch 155    / 1000   - loss = -4.739e+01 - val loss = -4.856e+01 -- est. : param_a = 1.854e+00, param_b = -9.068e-01, param_noise = 2.120e-01
# Epoch 156    / 1000   - loss = -4.856e+01 - val loss = -4.971e+01 -- est. : param_a = 1.864e+00, param_b = -9.117e-01, param_noise = 2.094e-01
# Epoch 157    / 1000   - loss = -4.971e+01 - val loss = -5.084e+01 -- est. : param_a = 1.874e+00, param_b = -9.165e-01, param_noise = 2.069e-01
# Epoch 158    / 1000   - loss = -5.084e+01 - val loss = -5.196e+01 -- est. : param_a = 1.883e+00, param_b = -9.212e-01, param_noise = 2.044e-01
# Epoch 159    / 1000   - loss = -5.196e+01 - val loss = -5.305e+01 -- est. : param_a = 1.892e+00, param_b = -9.257e-01, param_noise = 2.019e-01
# Epoch 160    / 1000   - loss = -5.305e+01 - val loss = -5.411e+01 -- est. : param_a = 1.901e+00, param_b = -9.302e-01, param_noise = 1.995e-01
# Epoch 161    / 1000   - loss = -5.411e+01 - val loss = -5.516e+01 -- est. : param_a = 1.910e+00, param_b = -9.346e-01, param_noise = 1.971e-01
# Epoch 162    / 1000   - loss = -5.516e+01 - val loss = -5.618e+01 -- est. : param_a = 1.918e+00, param_b = -9.388e-01, param_noise = 1.947e-01
# Epoch 163    / 1000   - loss = -5.618e+01 - val loss = -5.718e+01 -- est. : param_a = 1.926e+00, param_b = -9.429e-01, param_noise = 1.924e-01
# Epoch 164    / 1000   - loss = -5.718e+01 - val loss = -5.816e+01 -- est. : param_a = 1.934e+00, param_b = -9.469e-01, param_noise = 1.901e-01
# Epoch 165    / 1000   - loss = -5.816e+01 - val loss = -5.911e+01 -- est. : param_a = 1.942e+00, param_b = -9.507e-01, param_noise = 1.878e-01
# Epoch 166    / 1000   - loss = -5.911e+01 - val loss = -6.003e+01 -- est. : param_a = 1.949e+00, param_b = -9.544e-01, param_noise = 1.856e-01
# Epoch 167    / 1000   - loss = -6.003e+01 - val loss = -6.094e+01 -- est. : param_a = 1.956e+00, param_b = -9.579e-01, param_noise = 1.834e-01
# Epoch 168    / 1000   - loss = -6.094e+01 - val loss = -6.181e+01 -- est. : param_a = 1.963e+00, param_b = -9.614e-01, param_noise = 1.812e-01
# Epoch 169    / 1000   - loss = -6.181e+01 - val loss = -6.266e+01 -- est. : param_a = 1.970e+00, param_b = -9.646e-01, param_noise = 1.791e-01
# Epoch 170    / 1000   - loss = -6.266e+01 - val loss = -6.349e+01 -- est. : param_a = 1.976e+00, param_b = -9.678e-01, param_noise = 1.770e-01
# Epoch 171    / 1000   - loss = -6.349e+01 - val loss = -6.430e+01 -- est. : param_a = 1.982e+00, param_b = -9.704e-01, param_noise = 1.750e-01
# Epoch 172    / 1000   - loss = -6.430e+01 - val loss = -6.507e+01 -- est. : param_a = 1.987e+00, param_b = -9.738e-01, param_noise = 1.730e-01
# Epoch 173    / 1000   - loss = -6.507e+01 - val loss = -6.583e+01 -- est. : param_a = 1.992e+00, param_b = -9.747e-01, param_noise = 1.710e-01
# Epoch 174    / 1000   - loss = -6.583e+01 - val loss = -6.655e+01 -- est. : param_a = 1.997e+00, param_b = -9.812e-01, param_noise = 1.690e-01
# Epoch 175    / 1000   - loss = -6.655e+01 - val loss = -6.724e+01 -- est. : param_a = 2.002e+00, param_b = -9.764e-01, param_noise = 1.671e-01
# Epoch 176    / 1000   - loss = -6.724e+01 - val loss = -6.796e+01 -- est. : param_a = 2.006e+00, param_b = -9.831e-01, param_noise = 1.653e-01
# Epoch 177    / 1000   - loss = -6.796e+01 - val loss = -6.860e+01 -- est. : param_a = 2.010e+00, param_b = -9.884e-01, param_noise = 1.635e-01
# Epoch 178    / 1000   - loss = -6.860e+01 - val loss = -6.927e+01 -- est. : param_a = 2.013e+00, param_b = -9.852e-01, param_noise = 1.617e-01
# Epoch 179    / 1000   - loss = -6.927e+01 - val loss = -6.987e+01 -- est. : param_a = 2.017e+00, param_b = -9.848e-01, param_noise = 1.599e-01
# Epoch 180    / 1000   - loss = -6.987e+01 - val loss = -7.050e+01 -- est. : param_a = 2.019e+00, param_b = -9.903e-01, param_noise = 1.582e-01
# Epoch 181    / 1000   - loss = -7.050e+01 - val loss = -7.107e+01 -- est. : param_a = 2.022e+00, param_b = -9.936e-01, param_noise = 1.565e-01
# Epoch 182    / 1000   - loss = -7.107e+01 - val loss = -7.165e+01 -- est. : param_a = 2.024e+00, param_b = -9.914e-01, param_noise = 1.549e-01
# Epoch 183    / 1000   - loss = -7.165e+01 - val loss = -7.219e+01 -- est. : param_a = 2.026e+00, param_b = -9.901e-01, param_noise = 1.533e-01
# Epoch 184    / 1000   - loss = -7.219e+01 - val loss = -7.274e+01 -- est. : param_a = 2.028e+00, param_b = -9.935e-01, param_noise = 1.517e-01
# Epoch 185    / 1000   - loss = -7.274e+01 - val loss = -7.325e+01 -- est. : param_a = 2.029e+00, param_b = -9.966e-01, param_noise = 1.502e-01
# Epoch 186    / 1000   - loss = -7.325e+01 - val loss = -7.376e+01 -- est. : param_a = 2.030e+00, param_b = -9.952e-01, param_noise = 1.487e-01
# Epoch 187    / 1000   - loss = -7.376e+01 - val loss = -7.424e+01 -- est. : param_a = 2.031e+00, param_b = -9.930e-01, param_noise = 1.472e-01
# Epoch 188    / 1000   - loss = -7.424e+01 - val loss = -7.472e+01 -- est. : param_a = 2.031e+00, param_b = -9.946e-01, param_noise = 1.458e-01
# Epoch 189    / 1000   - loss = -7.472e+01 - val loss = -7.517e+01 -- est. : param_a = 2.031e+00, param_b = -9.973e-01, param_noise = 1.444e-01
# Epoch 190    / 1000   - loss = -7.517e+01 - val loss = -7.561e+01 -- est. : param_a = 2.031e+00, param_b = -9.965e-01, param_noise = 1.430e-01
# Epoch 191    / 1000   - loss = -7.561e+01 - val loss = -7.604e+01 -- est. : param_a = 2.031e+00, param_b = -9.940e-01, param_noise = 1.417e-01
# Epoch 192    / 1000   - loss = -7.604e+01 - val loss = -7.645e+01 -- est. : param_a = 2.031e+00, param_b = -9.942e-01, param_noise = 1.404e-01
# Epoch 193    / 1000   - loss = -7.645e+01 - val loss = -7.685e+01 -- est. : param_a = 2.030e+00, param_b = -9.962e-01, param_noise = 1.391e-01
# Epoch 194    / 1000   - loss = -7.685e+01 - val loss = -7.723e+01 -- est. : param_a = 2.030e+00, param_b = -9.957e-01, param_noise = 1.379e-01
# Epoch 195    / 1000   - loss = -7.723e+01 - val loss = -7.760e+01 -- est. : param_a = 2.029e+00, param_b = -9.933e-01, param_noise = 1.367e-01
# Epoch 196    / 1000   - loss = -7.760e+01 - val loss = -7.796e+01 -- est. : param_a = 2.028e+00, param_b = -9.928e-01, param_noise = 1.355e-01
# Epoch 197    / 1000   - loss = -7.796e+01 - val loss = -7.830e+01 -- est. : param_a = 2.027e+00, param_b = -9.941e-01, param_noise = 1.344e-01
# Epoch 198    / 1000   - loss = -7.830e+01 - val loss = -7.862e+01 -- est. : param_a = 2.026e+00, param_b = -9.937e-01, param_noise = 1.333e-01
# Epoch 199    / 1000   - loss = -7.862e+01 - val loss = -7.893e+01 -- est. : param_a = 2.025e+00, param_b = -9.915e-01, param_noise = 1.322e-01
# Epoch 200    / 1000   - loss = -7.893e+01 - val loss = -7.923e+01 -- est. : param_a = 2.024e+00, param_b = -9.908e-01, param_noise = 1.312e-01
# Epoch 201    / 1000   - loss = -7.923e+01 - val loss = -7.951e+01 -- est. : param_a = 2.022e+00, param_b = -9.917e-01, param_noise = 1.301e-01
# Epoch 202    / 1000   - loss = -7.951e+01 - val loss = -7.978e+01 -- est. : param_a = 2.021e+00, param_b = -9.911e-01, param_noise = 1.291e-01
# Epoch 203    / 1000   - loss = -7.978e+01 - val loss = -8.003e+01 -- est. : param_a = 2.020e+00, param_b = -9.892e-01, param_noise = 1.282e-01
# Epoch 204    / 1000   - loss = -8.003e+01 - val loss = -8.028e+01 -- est. : param_a = 2.019e+00, param_b = -9.888e-01, param_noise = 1.272e-01
# Epoch 205    / 1000   - loss = -8.028e+01 - val loss = -8.050e+01 -- est. : param_a = 2.018e+00, param_b = -9.894e-01, param_noise = 1.263e-01
# Epoch 206    / 1000   - loss = -8.050e+01 - val loss = -8.072e+01 -- est. : param_a = 2.017e+00, param_b = -9.885e-01, param_noise = 1.254e-01
# Epoch 207    / 1000   - loss = -8.072e+01 - val loss = -8.093e+01 -- est. : param_a = 2.016e+00, param_b = -9.870e-01, param_noise = 1.246e-01
# Epoch 208    / 1000   - loss = -8.093e+01 - val loss = -8.112e+01 -- est. : param_a = 2.015e+00, param_b = -9.871e-01, param_noise = 1.237e-01
# Epoch 209    / 1000   - loss = -8.112e+01 - val loss = -8.130e+01 -- est. : param_a = 2.014e+00, param_b = -9.875e-01, param_noise = 1.229e-01
# Epoch 210    / 1000   - loss = -8.130e+01 - val loss = -8.147e+01 -- est. : param_a = 2.013e+00, param_b = -9.864e-01, param_noise = 1.221e-01
# Epoch 211    / 1000   - loss = -8.147e+01 - val loss = -8.163e+01 -- est. : param_a = 2.013e+00, param_b = -9.856e-01, param_noise = 1.214e-01
# Epoch 212    / 1000   - loss = -8.163e+01 - val loss = -8.178e+01 -- est. : param_a = 2.012e+00, param_b = -9.861e-01, param_noise = 1.207e-01
# Epoch 213    / 1000   - loss = -8.178e+01 - val loss = -8.192e+01 -- est. : param_a = 2.012e+00, param_b = -9.860e-01, param_noise = 1.199e-01
# Epoch 214    / 1000   - loss = -8.192e+01 - val loss = -8.205e+01 -- est. : param_a = 2.011e+00, param_b = -9.850e-01, param_noise = 1.193e-01
# Epoch 215    / 1000   - loss = -8.205e+01 - val loss = -8.218e+01 -- est. : param_a = 2.011e+00, param_b = -9.851e-01, param_noise = 1.186e-01
# Epoch 216    / 1000   - loss = -8.218e+01 - val loss = -8.229e+01 -- est. : param_a = 2.011e+00, param_b = -9.856e-01, param_noise = 1.179e-01
# Epoch 217    / 1000   - loss = -8.229e+01 - val loss = -8.240e+01 -- est. : param_a = 2.011e+00, param_b = -9.851e-01, param_noise = 1.173e-01
# Epoch 218    / 1000   - loss = -8.240e+01 - val loss = -8.250e+01 -- est. : param_a = 2.011e+00, param_b = -9.847e-01, param_noise = 1.167e-01
# Epoch 219    / 1000   - loss = -8.250e+01 - val loss = -8.260e+01 -- est. : param_a = 2.011e+00, param_b = -9.854e-01, param_noise = 1.161e-01
# Epoch 220    / 1000   - loss = -8.260e+01 - val loss = -8.268e+01 -- est. : param_a = 2.011e+00, param_b = -9.854e-01, param_noise = 1.156e-01
# Epoch 221    / 1000   - loss = -8.268e+01 - val loss = -8.276e+01 -- est. : param_a = 2.011e+00, param_b = -9.849e-01, param_noise = 1.150e-01
# Epoch 222    / 1000   - loss = -8.276e+01 - val loss = -8.284e+01 -- est. : param_a = 2.011e+00, param_b = -9.854e-01, param_noise = 1.145e-01
# Epoch 223    / 1000   - loss = -8.284e+01 - val loss = -8.291e+01 -- est. : param_a = 2.012e+00, param_b = -9.858e-01, param_noise = 1.140e-01
# Epoch 224    / 1000   - loss = -8.291e+01 - val loss = -8.297e+01 -- est. : param_a = 2.012e+00, param_b = -9.854e-01, param_noise = 1.135e-01
# Epoch 225    / 1000   - loss = -8.297e+01 - val loss = -8.303e+01 -- est. : param_a = 2.012e+00, param_b = -9.857e-01, param_noise = 1.131e-01
# Epoch 226    / 1000   - loss = -8.303e+01 - val loss = -8.308e+01 -- est. : param_a = 2.012e+00, param_b = -9.863e-01, param_noise = 1.126e-01
# Epoch 227    / 1000   - loss = -8.308e+01 - val loss = -8.313e+01 -- est. : param_a = 2.013e+00, param_b = -9.860e-01, param_noise = 1.122e-01
# Epoch 228    / 1000   - loss = -8.313e+01 - val loss = -8.318e+01 -- est. : param_a = 2.013e+00, param_b = -9.862e-01, param_noise = 1.118e-01
# Epoch 229    / 1000   - loss = -8.318e+01 - val loss = -8.322e+01 -- est. : param_a = 2.013e+00, param_b = -9.868e-01, param_noise = 1.114e-01
# Epoch 230    / 1000   - loss = -8.322e+01 - val loss = -8.326e+01 -- est. : param_a = 2.014e+00, param_b = -9.866e-01, param_noise = 1.110e-01
# Epoch 231    / 1000   - loss = -8.326e+01 - val loss = -8.329e+01 -- est. : param_a = 2.014e+00, param_b = -9.867e-01, param_noise = 1.107e-01
# Epoch 232    / 1000   - loss = -8.329e+01 - val loss = -8.332e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.103e-01
# Epoch 233    / 1000   - loss = -8.332e+01 - val loss = -8.335e+01 -- est. : param_a = 2.015e+00, param_b = -9.871e-01, param_noise = 1.100e-01
# Epoch 234    / 1000   - loss = -8.335e+01 - val loss = -8.338e+01 -- est. : param_a = 2.015e+00, param_b = -9.871e-01, param_noise = 1.097e-01
# Epoch 235    / 1000   - loss = -8.338e+01 - val loss = -8.340e+01 -- est. : param_a = 2.015e+00, param_b = -9.875e-01, param_noise = 1.094e-01
# Epoch 236    / 1000   - loss = -8.340e+01 - val loss = -8.342e+01 -- est. : param_a = 2.015e+00, param_b = -9.873e-01, param_noise = 1.091e-01
# Epoch 237    / 1000   - loss = -8.342e+01 - val loss = -8.344e+01 -- est. : param_a = 2.015e+00, param_b = -9.873e-01, param_noise = 1.088e-01
# Epoch 238    / 1000   - loss = -8.344e+01 - val loss = -8.345e+01 -- est. : param_a = 2.015e+00, param_b = -9.877e-01, param_noise = 1.086e-01
# Epoch 239    / 1000   - loss = -8.345e+01 - val loss = -8.347e+01 -- est. : param_a = 2.016e+00, param_b = -9.875e-01, param_noise = 1.083e-01
# Epoch 240    / 1000   - loss = -8.347e+01 - val loss = -8.348e+01 -- est. : param_a = 2.016e+00, param_b = -9.875e-01, param_noise = 1.081e-01
# Epoch 241    / 1000   - loss = -8.348e+01 - val loss = -8.349e+01 -- est. : param_a = 2.016e+00, param_b = -9.877e-01, param_noise = 1.078e-01
# Epoch 242    / 1000   - loss = -8.349e+01 - val loss = -8.350e+01 -- est. : param_a = 2.016e+00, param_b = -9.875e-01, param_noise = 1.076e-01
# Epoch 243    / 1000   - loss = -8.350e+01 - val loss = -8.351e+01 -- est. : param_a = 2.015e+00, param_b = -9.875e-01, param_noise = 1.074e-01
# Epoch 244    / 1000   - loss = -8.351e+01 - val loss = -8.352e+01 -- est. : param_a = 2.015e+00, param_b = -9.876e-01, param_noise = 1.072e-01
# Epoch 245    / 1000   - loss = -8.352e+01 - val loss = -8.353e+01 -- est. : param_a = 2.015e+00, param_b = -9.873e-01, param_noise = 1.071e-01
# Epoch 246    / 1000   - loss = -8.353e+01 - val loss = -8.353e+01 -- est. : param_a = 2.015e+00, param_b = -9.874e-01, param_noise = 1.069e-01
# Epoch 247    / 1000   - loss = -8.353e+01 - val loss = -8.354e+01 -- est. : param_a = 2.015e+00, param_b = -9.874e-01, param_noise = 1.067e-01
# Epoch 248    / 1000   - loss = -8.354e+01 - val loss = -8.354e+01 -- est. : param_a = 2.015e+00, param_b = -9.872e-01, param_noise = 1.066e-01
# Epoch 249    / 1000   - loss = -8.354e+01 - val loss = -8.355e+01 -- est. : param_a = 2.015e+00, param_b = -9.873e-01, param_noise = 1.064e-01
# Epoch 250    / 1000   - loss = -8.355e+01 - val loss = -8.355e+01 -- est. : param_a = 2.015e+00, param_b = -9.872e-01, param_noise = 1.063e-01
# Epoch 251    / 1000   - loss = -8.355e+01 - val loss = -8.355e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.062e-01
# Epoch 252    / 1000   - loss = -8.355e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.871e-01, param_noise = 1.060e-01
# Epoch 253    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.059e-01
# Epoch 254    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.058e-01
# Epoch 255    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.057e-01
# Epoch 256    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.056e-01
# Epoch 257    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.055e-01
# Epoch 258    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.055e-01
# Epoch 259    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.054e-01
# Epoch 260    / 1000   - loss = -8.356e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.053e-01
# Epoch 261    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.053e-01
# Epoch 262    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.052e-01
# Epoch 263    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.051e-01
# Epoch 264    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.051e-01
# Epoch 265    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.051e-01
# Epoch 266    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.050e-01
# Epoch 267    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.050e-01
# Epoch 268    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 269    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 270    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 271    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 272    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.048e-01
# Epoch 273    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 274    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 275    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 276    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 277    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 278    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.871e-01, param_noise = 1.047e-01
# Epoch 279    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 280    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 281    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.871e-01, param_noise = 1.047e-01
# Epoch 282    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 283    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.871e-01, param_noise = 1.047e-01
# Epoch 284    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 285    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 286    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 287    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.015e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 288    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 289    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 290    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 291    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 292    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 293    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 294    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 295    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.047e-01
# Epoch 296    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 297    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 298    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 299    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 300    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 301    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 302    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 303    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 304    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 305    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 306    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 307    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 308    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 309    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 310    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 311    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 312    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 313    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.048e-01
# Epoch 314    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 315    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 316    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 317    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 318    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 319    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 320    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 321    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 322    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 323    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 324    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 325    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 326    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 327    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 328    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 329    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 330    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 331    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 332    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 333    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 334    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 335    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 336    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 337    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# ...
# Epoch 890    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 891    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 892    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 893    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 894    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 895    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 896    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 897    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 898    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 899    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 900    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 901    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 902    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 903    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 904    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 905    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 906    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 907    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 908    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 909    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 910    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 911    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 912    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 913    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 914    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 915    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 916    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 917    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 918    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 919    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 920    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 921    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 922    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 923    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 924    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 925    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 926    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 927    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 928    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 929    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 930    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 931    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 932    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 933    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 934    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 935    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 936    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 937    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 938    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 939    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 940    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 941    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 942    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 943    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 944    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 945    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 946    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 947    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 948    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 949    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 950    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.871e-01, param_noise = 1.049e-01
# Epoch 951    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 952    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.871e-01, param_noise = 1.049e-01
# Epoch 953    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.049e-01
# Epoch 954    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.049e-01
# Epoch 955    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.867e-01, param_noise = 1.049e-01
# Epoch 956    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.874e-01, param_noise = 1.049e-01
# Epoch 957    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.865e-01, param_noise = 1.049e-01
# Epoch 958    / 1000   - loss = -8.357e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.876e-01, param_noise = 1.049e-01
# Epoch 959    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.862e-01, param_noise = 1.049e-01
# Epoch 960    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.879e-01, param_noise = 1.049e-01
# Epoch 961    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.859e-01, param_noise = 1.049e-01
# Epoch 962    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.883e-01, param_noise = 1.049e-01
# Epoch 963    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.857e-01, param_noise = 1.049e-01
# Epoch 964    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.881e-01, param_noise = 1.049e-01
# Epoch 965    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.862e-01, param_noise = 1.049e-01
# Epoch 966    / 1000   - loss = -8.356e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.873e-01, param_noise = 1.049e-01
# Epoch 967    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.049e-01
# Epoch 968    / 1000   - loss = -8.357e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.864e-01, param_noise = 1.049e-01
# Epoch 969    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.014e+00, param_b = -9.878e-01, param_noise = 1.049e-01
# Epoch 970    / 1000   - loss = -8.356e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.862e-01, param_noise = 1.049e-01
# Epoch 971    / 1000   - loss = -8.356e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.876e-01, param_noise = 1.049e-01
# Epoch 972    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.049e-01
# Epoch 973    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.049e-01
# Epoch 974    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.875e-01, param_noise = 1.049e-01
# Epoch 975    / 1000   - loss = -8.357e+01 - val loss = -8.356e+01 -- est. : param_a = 2.015e+00, param_b = -9.864e-01, param_noise = 1.049e-01
# Epoch 976    / 1000   - loss = -8.356e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.875e-01, param_noise = 1.049e-01
# Epoch 977    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.866e-01, param_noise = 1.049e-01
# Epoch 978    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 979    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.049e-01
# Epoch 980    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.866e-01, param_noise = 1.049e-01
# Epoch 981    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.874e-01, param_noise = 1.049e-01
# Epoch 982    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.866e-01, param_noise = 1.049e-01
# Epoch 983    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.871e-01, param_noise = 1.049e-01
# Epoch 984    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.871e-01, param_noise = 1.049e-01
# Epoch 985    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.867e-01, param_noise = 1.049e-01
# Epoch 986    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.873e-01, param_noise = 1.049e-01
# Epoch 987    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.867e-01, param_noise = 1.049e-01
# Epoch 988    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.049e-01
# Epoch 989    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01
# Epoch 990    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.049e-01
# Epoch 991    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.049e-01
# Epoch 992    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.867e-01, param_noise = 1.049e-01
# Epoch 993    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.049e-01
# Epoch 994    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 995    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 996    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.871e-01, param_noise = 1.049e-01
# Epoch 997    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.868e-01, param_noise = 1.049e-01
# Epoch 998    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.872e-01, param_noise = 1.049e-01
# Epoch 999    / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.869e-01, param_noise = 1.049e-01
# Epoch 1000   / 1000   - loss = -8.357e+01 - val loss = -8.357e+01 -- est. : param_a = 2.014e+00, param_b = -9.870e-01, param_noise = 1.049e-01

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(training_losses, label='training')
ax.plot(validation_losses, label='validation')
ax.grid()
ax.legend()
plt.show()

print(f'param_a MLE = {pyro.param("param_a"):.3e} vs ground truth = {a.item():.3e}')
print(f'param_b MLE = {pyro.param("param_b"):.3e} vs ground truth = {b.item():.3e}')
print(f'param_noise MLE = {pyro.param("param_noise"):.3e} vs ground truth = {noise.item():.3e}')
# Out:
# param_a MLE = 2.014e+00 vs ground truth = 2.000e+00
# param_b MLE = -9.870e-01 vs ground truth = -1.000e+00
# param_noise MLE = 1.049e-01 vs ground truth = 1.000e-01

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 30px; color: black; font-weight: bold;">
# 2 : learnable posterior distributions with SVI
# </div>
#
# Now we posit that the parameters are R.V. and perform SVI

# %% [markdown]
# `pyro.plate` is the Pyro's representation of the plate notation in graphical models.
#
# It is a **context manager** that informs Pyro which parts of the model should be considered conditionnally indepedent.
# - the set of random variables inside the `with pyro.plate(..)`are conditionally independent given all variables outside the plate.
# - allows vectorization on GPU
# - adding the `subsample_size` (`with pyro.plate("data", size=len(X), subsample_size=batch_size)): ...`) allows the use of mini-batches in large datasets.

# %%
# model : updated with priors declared with pyro.sample

def model(X, y=None):
    
    # inputs: ----------------------
    #   X : torch.tensor(size,1)
    #   y : torch.tensor(size,1) if provided
    
    # priors ------------------------
    param_a = pyro.sample("a", dist.Normal(0.0,1.0))
    param_b = pyro.sample("b", dist.Normal(0.0,1.0))
    
    # Trick : using a HalfNormal for the standard deviation param_noise
    # creates gradient instability as the reparametrization trick does not apply well on HalfNormal
    # so we use a log Normal prior instead 
    # (ie Noraml then exponentiate for the likelihood computation)
    log_noise_std = pyro.sample("log_noise_std", dist.Normal(0.0,1.0))
    param_noise = torch.exp(log_noise_std)
    
    # gaussian likelihood ----------------------------
    means = X * param_a + param_b
    with pyro.plate("data", len(X)):
        y_hat = pyro.sample("obs", dist.Normal(means, param_noise), obs=y)
    # return is optional :
    #   - If y is None, this is a sample (tensor)
    #   - If y is given, this is the log likelihood
    
    return y_hat

# %% [markdown]
# The `guide` function declares the approximate posterior for the SVI.
# It serves as the container for all the learnable parameters and stochastic *sites* (latent variables) that the define the approximate posterior.
#
# - it must define a *surrogate* probability distribution for each single latent variable (= unobserved) `pyro.sample` defined in the `model`. Names must be the same.
# - no likelihood calculation, ie no `pyro.sample("obs",...)` or RV with `obs=y`.
# - the distributions within `guide` must be parameterized by `pyro.param` : those are the variational parameters $\phi$
# - the posterior can be factorized (mean-field) or not.
# - the `guide` signature must be exactly the same as `model` (ie `(X, y=None)` for example). This allows alignment for the different handlers.

# %%
# approximate posterior for a,b and noise
# here, mean-field approximation - posteriors factorize
# NB : just posteriors, no likelihood !

def q_phi(X, y=None):
    
    # a : gaussian posterior with learnable parameters a_loc and a_scale
    a_loc = pyro.param("a_loc", torch.tensor((0.0)).to(device))
    a_scale = pyro.param("a_scale", torch.tensor((0.1)).to(device), constraint=constraints.positive)
    pyro.sample("a", dist.Normal(a_loc, a_scale))
    
    # b : gaussian posterior with learnable parameters b_loc and b_scale
    b_loc = pyro.param("b_loc", torch.tensor((0.0)).to(device))
    b_scale = pyro.param("b_scale", torch.tensor((0.1)).to(device), constraint=constraints.positive)
    pyro.sample("b", dist.Normal(b_loc, b_scale))
    
    # noise : gaussian posterior for the log noise standard deviation
    log_noise_std_loc = pyro.param("log_noise_std_loc", torch.tensor((-2.0)).to(device))
    log_noise_std_scale = pyro.param("log_noise_std_std", torch.tensor(0.1).to(device), constraint=constraints.positive)
    pyro.sample("log_noise_std", dist.Normal(log_noise_std_loc, log_noise_std_scale))
    return

# %%
pyro.clear_param_store() # Clear old parameters

# optimizer
optimizer = Adam(
    {"lr": 5e-3}
)

# the SVI engine
K = 3 # number of samples used for the estimation of the expectation
svi = SVI(
    model=model,
    guide=q_phi,
    optim=optimizer,
    loss=Trace_ELBO(num_particles=K)
)

# %%
n_epochs = 2000
training_losses = []
validation_losses = []

for step in range(n_epochs):
    # perform the training and evaluation
    loss = svi.step(X,y)
    eval_loss = svi.evaluate_loss(X,y)
    # log
    training_losses.append(loss)
    validation_losses.append(eval_loss)
    # report out
    print(f'Epoch {step+1:<6} / {n_epochs:<6} - loss = {loss:.3e} - val loss = {eval_loss:.3e}')
# Out:
# Epoch 1      / 2000   - loss = 7.743e+02 - val loss = 7.805e+02
# Epoch 2      / 2000   - loss = 1.137e+03 - val loss = 7.335e+02
# Epoch 3      / 2000   - loss = 8.940e+02 - val loss = 8.791e+02
# Epoch 4      / 2000   - loss = 8.651e+02 - val loss = 9.154e+02
# Epoch 5      / 2000   - loss = 8.024e+02 - val loss = 7.546e+02
# Epoch 6      / 2000   - loss = 7.775e+02 - val loss = 7.100e+02
# Epoch 7      / 2000   - loss = 9.648e+02 - val loss = 6.347e+02
# Epoch 8      / 2000   - loss = 1.124e+03 - val loss = 1.012e+03
# Epoch 9      / 2000   - loss = 7.560e+02 - val loss = 8.723e+02
# Epoch 10     / 2000   - loss = 7.633e+02 - val loss = 8.118e+02
# Epoch 11     / 2000   - loss = 7.899e+02 - val loss = 5.693e+02
# Epoch 12     / 2000   - loss = 7.849e+02 - val loss = 6.455e+02
# Epoch 13     / 2000   - loss = 7.212e+02 - val loss = 6.439e+02
# Epoch 14     / 2000   - loss = 8.198e+02 - val loss = 6.539e+02
# Epoch 15     / 2000   - loss = 5.511e+02 - val loss = 6.346e+02
# Epoch 16     / 2000   - loss = 6.297e+02 - val loss = 1.037e+03
# Epoch 17     / 2000   - loss = 7.943e+02 - val loss = 6.378e+02
# Epoch 18     / 2000   - loss = 7.472e+02 - val loss = 8.526e+02
# Epoch 19     / 2000   - loss = 7.343e+02 - val loss = 7.784e+02
# Epoch 20     / 2000   - loss = 7.181e+02 - val loss = 5.467e+02
# Epoch 21     / 2000   - loss = 5.623e+02 - val loss = 7.763e+02
# Epoch 22     / 2000   - loss = 7.634e+02 - val loss = 6.246e+02
# Epoch 23     / 2000   - loss = 5.711e+02 - val loss = 5.650e+02
# Epoch 24     / 2000   - loss = 6.096e+02 - val loss = 5.516e+02
# Epoch 25     / 2000   - loss = 8.268e+02 - val loss = 8.891e+02
# Epoch 26     / 2000   - loss = 6.571e+02 - val loss = 7.058e+02
# Epoch 27     / 2000   - loss = 6.772e+02 - val loss = 5.705e+02
# Epoch 28     / 2000   - loss = 6.162e+02 - val loss = 5.439e+02
# Epoch 29     / 2000   - loss = 6.973e+02 - val loss = 4.739e+02
# Epoch 30     / 2000   - loss = 4.929e+02 - val loss = 7.958e+02
# Epoch 31     / 2000   - loss = 6.248e+02 - val loss = 5.536e+02
# Epoch 32     / 2000   - loss = 5.649e+02 - val loss = 4.479e+02
# Epoch 33     / 2000   - loss = 5.602e+02 - val loss = 5.202e+02
# Epoch 34     / 2000   - loss = 6.966e+02 - val loss = 5.978e+02
# Epoch 35     / 2000   - loss = 5.388e+02 - val loss = 4.518e+02
# Epoch 36     / 2000   - loss = 6.510e+02 - val loss = 6.493e+02
# Epoch 37     / 2000   - loss = 5.225e+02 - val loss = 5.485e+02
# Epoch 38     / 2000   - loss = 4.897e+02 - val loss = 5.448e+02
# Epoch 39     / 2000   - loss = 5.164e+02 - val loss = 5.493e+02
# Epoch 40     / 2000   - loss = 4.767e+02 - val loss = 5.693e+02
# Epoch 41     / 2000   - loss = 5.322e+02 - val loss = 5.014e+02
# Epoch 42     / 2000   - loss = 4.123e+02 - val loss = 5.130e+02
# Epoch 43     / 2000   - loss = 5.156e+02 - val loss = 4.536e+02
# Epoch 44     / 2000   - loss = 4.603e+02 - val loss = 4.360e+02
# Epoch 45     / 2000   - loss = 5.566e+02 - val loss = 4.652e+02
# Epoch 46     / 2000   - loss = 4.132e+02 - val loss = 4.292e+02
# Epoch 47     / 2000   - loss = 5.128e+02 - val loss = 4.500e+02
# Epoch 48     / 2000   - loss = 5.034e+02 - val loss = 4.654e+02
# Epoch 49     / 2000   - loss = 5.594e+02 - val loss = 4.983e+02
# Epoch 50     / 2000   - loss = 4.824e+02 - val loss = 4.256e+02
# Epoch 51     / 2000   - loss = 4.110e+02 - val loss = 3.769e+02
# Epoch 52     / 2000   - loss = 3.722e+02 - val loss = 3.899e+02
# Epoch 53     / 2000   - loss = 3.243e+02 - val loss = 4.372e+02
# Epoch 54     / 2000   - loss = 3.848e+02 - val loss = 4.091e+02
# Epoch 55     / 2000   - loss = 4.204e+02 - val loss = 3.740e+02
# Epoch 56     / 2000   - loss = 3.992e+02 - val loss = 3.758e+02
# Epoch 57     / 2000   - loss = 4.690e+02 - val loss = 4.258e+02
# Epoch 58     / 2000   - loss = 4.910e+02 - val loss = 3.345e+02
# Epoch 59     / 2000   - loss = 3.763e+02 - val loss = 3.839e+02
# Epoch 60     / 2000   - loss = 3.862e+02 - val loss = 3.948e+02
# Epoch 61     / 2000   - loss = 3.857e+02 - val loss = 4.415e+02
# Epoch 62     / 2000   - loss = 4.382e+02 - val loss = 3.955e+02
# Epoch 63     / 2000   - loss = 3.225e+02 - val loss = 3.629e+02
# Epoch 64     / 2000   - loss = 4.239e+02 - val loss = 4.605e+02
# Epoch 65     / 2000   - loss = 4.431e+02 - val loss = 4.140e+02
# Epoch 66     / 2000   - loss = 4.122e+02 - val loss = 4.317e+02
# Epoch 67     / 2000   - loss = 3.620e+02 - val loss = 3.911e+02
# Epoch 68     / 2000   - loss = 3.434e+02 - val loss = 3.184e+02
# Epoch 69     / 2000   - loss = 2.924e+02 - val loss = 3.748e+02
# Epoch 70     / 2000   - loss = 2.939e+02 - val loss = 3.469e+02
# Epoch 71     / 2000   - loss = 2.650e+02 - val loss = 3.642e+02
# Epoch 72     / 2000   - loss = 3.649e+02 - val loss = 3.398e+02
# Epoch 73     / 2000   - loss = 2.795e+02 - val loss = 3.327e+02
# Epoch 74     / 2000   - loss = 3.768e+02 - val loss = 3.223e+02
# Epoch 75     / 2000   - loss = 3.259e+02 - val loss = 3.594e+02
# Epoch 76     / 2000   - loss = 3.839e+02 - val loss = 2.289e+02
# Epoch 77     / 2000   - loss = 3.475e+02 - val loss = 2.748e+02
# Epoch 78     / 2000   - loss = 2.789e+02 - val loss = 2.390e+02
# Epoch 79     / 2000   - loss = 2.421e+02 - val loss = 2.734e+02
# Epoch 80     / 2000   - loss = 3.722e+02 - val loss = 3.541e+02
# Epoch 81     / 2000   - loss = 3.238e+02 - val loss = 3.674e+02
# Epoch 82     / 2000   - loss = 3.066e+02 - val loss = 2.098e+02
# Epoch 83     / 2000   - loss = 2.675e+02 - val loss = 3.813e+02
# Epoch 84     / 2000   - loss = 2.777e+02 - val loss = 2.513e+02
# Epoch 85     / 2000   - loss = 3.001e+02 - val loss = 3.109e+02
# Epoch 86     / 2000   - loss = 2.795e+02 - val loss = 2.840e+02
# Epoch 87     / 2000   - loss = 2.888e+02 - val loss = 2.679e+02
# Epoch 88     / 2000   - loss = 2.898e+02 - val loss = 3.242e+02
# Epoch 89     / 2000   - loss = 2.786e+02 - val loss = 2.300e+02
# Epoch 90     / 2000   - loss = 2.805e+02 - val loss = 3.217e+02
# Epoch 91     / 2000   - loss = 3.436e+02 - val loss = 1.945e+02
# Epoch 92     / 2000   - loss = 3.321e+02 - val loss = 2.821e+02
# Epoch 93     / 2000   - loss = 2.991e+02 - val loss = 3.090e+02
# Epoch 94     / 2000   - loss = 2.267e+02 - val loss = 2.808e+02
# Epoch 95     / 2000   - loss = 3.296e+02 - val loss = 2.366e+02
# Epoch 96     / 2000   - loss = 3.032e+02 - val loss = 2.068e+02
# Epoch 97     / 2000   - loss = 2.242e+02 - val loss = 2.063e+02
# Epoch 98     / 2000   - loss = 2.397e+02 - val loss = 2.878e+02
# Epoch 99     / 2000   - loss = 2.452e+02 - val loss = 2.708e+02
# Epoch 100    / 2000   - loss = 2.120e+02 - val loss = 2.685e+02
# Epoch 101    / 2000   - loss = 2.942e+02 - val loss = 2.358e+02
# Epoch 102    / 2000   - loss = 1.947e+02 - val loss = 1.977e+02
# Epoch 103    / 2000   - loss = 3.176e+02 - val loss = 2.485e+02
# Epoch 104    / 2000   - loss = 2.394e+02 - val loss = 3.395e+02
# Epoch 105    / 2000   - loss = 2.419e+02 - val loss = 1.996e+02
# Epoch 106    / 2000   - loss = 2.345e+02 - val loss = 2.361e+02
# Epoch 107    / 2000   - loss = 2.730e+02 - val loss = 2.173e+02
# Epoch 108    / 2000   - loss = 2.044e+02 - val loss = 2.210e+02
# Epoch 109    / 2000   - loss = 1.954e+02 - val loss = 2.160e+02
# Epoch 110    / 2000   - loss = 2.476e+02 - val loss = 2.193e+02
# Epoch 111    / 2000   - loss = 1.915e+02 - val loss = 2.861e+02
# Epoch 112    / 2000   - loss = 1.885e+02 - val loss = 2.544e+02
# Epoch 113    / 2000   - loss = 1.718e+02 - val loss = 1.934e+02
# Epoch 114    / 2000   - loss = 2.504e+02 - val loss = 1.968e+02
# Epoch 115    / 2000   - loss = 2.201e+02 - val loss = 2.600e+02
# Epoch 116    / 2000   - loss = 2.410e+02 - val loss = 1.693e+02
# Epoch 117    / 2000   - loss = 1.722e+02 - val loss = 1.970e+02
# Epoch 118    / 2000   - loss = 2.013e+02 - val loss = 1.836e+02
# Epoch 119    / 2000   - loss = 2.061e+02 - val loss = 1.876e+02
# Epoch 120    / 2000   - loss = 2.049e+02 - val loss = 1.848e+02
# Epoch 121    / 2000   - loss = 2.098e+02 - val loss = 1.955e+02
# Epoch 122    / 2000   - loss = 2.175e+02 - val loss = 1.813e+02
# Epoch 123    / 2000   - loss = 1.962e+02 - val loss = 1.815e+02
# Epoch 124    / 2000   - loss = 1.904e+02 - val loss = 2.010e+02
# Epoch 125    / 2000   - loss = 2.170e+02 - val loss = 1.913e+02
# Epoch 126    / 2000   - loss = 2.294e+02 - val loss = 1.923e+02
# Epoch 127    / 2000   - loss = 1.928e+02 - val loss = 2.847e+02
# Epoch 128    / 2000   - loss = 1.726e+02 - val loss = 1.739e+02
# Epoch 129    / 2000   - loss = 1.845e+02 - val loss = 1.601e+02
# Epoch 130    / 2000   - loss = 1.908e+02 - val loss = 2.199e+02
# Epoch 131    / 2000   - loss = 1.904e+02 - val loss = 2.374e+02
# Epoch 132    / 2000   - loss = 2.363e+02 - val loss = 1.475e+02
# Epoch 133    / 2000   - loss = 2.009e+02 - val loss = 1.696e+02
# Epoch 134    / 2000   - loss = 1.739e+02 - val loss = 1.922e+02
# Epoch 135    / 2000   - loss = 1.652e+02 - val loss = 1.669e+02
# Epoch 136    / 2000   - loss = 1.645e+02 - val loss = 2.042e+02
# Epoch 137    / 2000   - loss = 1.773e+02 - val loss = 1.921e+02
# Epoch 138    / 2000   - loss = 1.944e+02 - val loss = 2.026e+02
# Epoch 139    / 2000   - loss = 1.717e+02 - val loss = 1.511e+02
# Epoch 140    / 2000   - loss = 1.410e+02 - val loss = 1.614e+02
# Epoch 141    / 2000   - loss = 1.448e+02 - val loss = 1.365e+02
# Epoch 142    / 2000   - loss = 1.901e+02 - val loss = 1.800e+02
# Epoch 143    / 2000   - loss = 1.546e+02 - val loss = 1.800e+02
# Epoch 144    / 2000   - loss = 1.915e+02 - val loss = 1.805e+02
# Epoch 145    / 2000   - loss = 1.742e+02 - val loss = 2.160e+02
# Epoch 146    / 2000   - loss = 1.465e+02 - val loss = 2.117e+02
# Epoch 147    / 2000   - loss = 1.641e+02 - val loss = 1.611e+02
# Epoch 148    / 2000   - loss = 1.243e+02 - val loss = 1.349e+02
# Epoch 149    / 2000   - loss = 1.977e+02 - val loss = 1.593e+02
# Epoch 150    / 2000   - loss = 1.811e+02 - val loss = 1.649e+02
# Epoch 151    / 2000   - loss = 1.460e+02 - val loss = 1.491e+02
# Epoch 152    / 2000   - loss = 1.849e+02 - val loss = 1.563e+02
# Epoch 153    / 2000   - loss = 1.930e+02 - val loss = 1.951e+02
# Epoch 154    / 2000   - loss = 1.699e+02 - val loss = 1.514e+02
# Epoch 155    / 2000   - loss = 1.713e+02 - val loss = 1.737e+02
# Epoch 156    / 2000   - loss = 1.639e+02 - val loss = 1.543e+02
# Epoch 157    / 2000   - loss = 1.338e+02 - val loss = 1.641e+02
# Epoch 158    / 2000   - loss = 1.628e+02 - val loss = 1.411e+02
# Epoch 159    / 2000   - loss = 1.416e+02 - val loss = 1.704e+02
# Epoch 160    / 2000   - loss = 1.615e+02 - val loss = 1.545e+02
# Epoch 161    / 2000   - loss = 1.565e+02 - val loss = 1.439e+02
# Epoch 162    / 2000   - loss = 1.704e+02 - val loss = 1.604e+02
# Epoch 163    / 2000   - loss = 2.012e+02 - val loss = 1.950e+02
# Epoch 164    / 2000   - loss = 1.708e+02 - val loss = 1.290e+02
# Epoch 165    / 2000   - loss = 1.541e+02 - val loss = 1.650e+02
# Epoch 166    / 2000   - loss = 1.597e+02 - val loss = 1.583e+02
# Epoch 167    / 2000   - loss = 1.565e+02 - val loss = 1.465e+02
# Epoch 168    / 2000   - loss = 1.615e+02 - val loss = 1.347e+02
# Epoch 169    / 2000   - loss = 1.450e+02 - val loss = 1.640e+02
# Epoch 170    / 2000   - loss = 1.171e+02 - val loss = 1.504e+02
# Epoch 171    / 2000   - loss = 1.237e+02 - val loss = 1.471e+02
# Epoch 172    / 2000   - loss = 1.324e+02 - val loss = 1.287e+02
# Epoch 173    / 2000   - loss = 1.882e+02 - val loss = 1.441e+02
# Epoch 174    / 2000   - loss = 1.326e+02 - val loss = 1.448e+02
# Epoch 175    / 2000   - loss = 1.465e+02 - val loss = 1.322e+02
# Epoch 176    / 2000   - loss = 1.234e+02 - val loss = 1.521e+02
# Epoch 177    / 2000   - loss = 1.443e+02 - val loss = 1.193e+02
# Epoch 178    / 2000   - loss = 1.485e+02 - val loss = 1.400e+02
# Epoch 179    / 2000   - loss = 1.603e+02 - val loss = 1.107e+02
# Epoch 180    / 2000   - loss = 1.224e+02 - val loss = 1.242e+02
# Epoch 181    / 2000   - loss = 1.273e+02 - val loss = 1.301e+02
# Epoch 182    / 2000   - loss = 1.256e+02 - val loss = 1.257e+02
# Epoch 183    / 2000   - loss = 1.081e+02 - val loss = 1.412e+02
# Epoch 184    / 2000   - loss = 1.199e+02 - val loss = 1.520e+02
# Epoch 185    / 2000   - loss = 1.342e+02 - val loss = 1.382e+02
# Epoch 186    / 2000   - loss = 1.078e+02 - val loss = 1.318e+02
# Epoch 187    / 2000   - loss = 1.158e+02 - val loss = 1.051e+02
# Epoch 188    / 2000   - loss = 1.289e+02 - val loss = 1.205e+02
# Epoch 189    / 2000   - loss = 1.218e+02 - val loss = 1.242e+02
# Epoch 190    / 2000   - loss = 1.380e+02 - val loss = 1.363e+02
# Epoch 191    / 2000   - loss = 1.506e+02 - val loss = 1.222e+02
# Epoch 192    / 2000   - loss = 1.067e+02 - val loss = 1.105e+02
# Epoch 193    / 2000   - loss = 8.192e+01 - val loss = 1.136e+02
# Epoch 194    / 2000   - loss = 1.263e+02 - val loss = 1.272e+02
# Epoch 195    / 2000   - loss = 1.295e+02 - val loss = 1.157e+02
# Epoch 196    / 2000   - loss = 9.985e+01 - val loss = 1.015e+02
# Epoch 197    / 2000   - loss = 1.118e+02 - val loss = 1.067e+02
# Epoch 198    / 2000   - loss = 1.146e+02 - val loss = 1.048e+02
# Epoch 199    / 2000   - loss = 9.305e+01 - val loss = 1.324e+02
# Epoch 200    / 2000   - loss = 1.186e+02 - val loss = 1.069e+02
# Epoch 201    / 2000   - loss = 1.109e+02 - val loss = 7.748e+01
# Epoch 202    / 2000   - loss = 1.059e+02 - val loss = 1.138e+02
# Epoch 203    / 2000   - loss = 1.015e+02 - val loss = 1.050e+02
# Epoch 204    / 2000   - loss = 9.725e+01 - val loss = 9.874e+01
# Epoch 205    / 2000   - loss = 9.851e+01 - val loss = 1.105e+02
# Epoch 206    / 2000   - loss = 1.079e+02 - val loss = 1.173e+02
# Epoch 207    / 2000   - loss = 1.086e+02 - val loss = 9.779e+01
# Epoch 208    / 2000   - loss = 9.735e+01 - val loss = 1.113e+02
# Epoch 209    / 2000   - loss = 1.070e+02 - val loss = 1.229e+02
# Epoch 210    / 2000   - loss = 1.131e+02 - val loss = 9.921e+01
# Epoch 211    / 2000   - loss = 1.252e+02 - val loss = 1.105e+02
# Epoch 212    / 2000   - loss = 9.313e+01 - val loss = 9.693e+01
# Epoch 213    / 2000   - loss = 1.111e+02 - val loss = 1.061e+02
# Epoch 214    / 2000   - loss = 1.148e+02 - val loss = 1.061e+02
# Epoch 215    / 2000   - loss = 9.266e+01 - val loss = 9.468e+01
# Epoch 216    / 2000   - loss = 1.282e+02 - val loss = 9.298e+01
# Epoch 217    / 2000   - loss = 8.595e+01 - val loss = 8.699e+01
# Epoch 218    / 2000   - loss = 1.001e+02 - val loss = 7.148e+01
# Epoch 219    / 2000   - loss = 7.745e+01 - val loss = 1.035e+02
# Epoch 220    / 2000   - loss = 1.087e+02 - val loss = 9.356e+01
# Epoch 221    / 2000   - loss = 1.088e+02 - val loss = 9.218e+01
# Epoch 222    / 2000   - loss = 1.101e+02 - val loss = 1.052e+02
# Epoch 223    / 2000   - loss = 8.533e+01 - val loss = 1.013e+02
# Epoch 224    / 2000   - loss = 1.060e+02 - val loss = 9.106e+01
# Epoch 225    / 2000   - loss = 9.592e+01 - val loss = 1.020e+02
# Epoch 226    / 2000   - loss = 8.726e+01 - val loss = 7.925e+01
# Epoch 227    / 2000   - loss = 9.509e+01 - val loss = 1.229e+02
# Epoch 228    / 2000   - loss = 1.023e+02 - val loss = 1.113e+02
# Epoch 229    / 2000   - loss = 1.417e+02 - val loss = 8.814e+01
# Epoch 230    / 2000   - loss = 8.567e+01 - val loss = 8.858e+01
# Epoch 231    / 2000   - loss = 1.207e+02 - val loss = 8.764e+01
# Epoch 232    / 2000   - loss = 8.477e+01 - val loss = 1.143e+02
# Epoch 233    / 2000   - loss = 9.451e+01 - val loss = 7.842e+01
# Epoch 234    / 2000   - loss = 7.882e+01 - val loss = 8.377e+01
# Epoch 235    / 2000   - loss = 8.243e+01 - val loss = 9.549e+01
# Epoch 236    / 2000   - loss = 9.634e+01 - val loss = 9.509e+01
# Epoch 237    / 2000   - loss = 8.099e+01 - val loss = 8.814e+01
# Epoch 238    / 2000   - loss = 9.833e+01 - val loss = 8.759e+01
# Epoch 239    / 2000   - loss = 9.772e+01 - val loss = 9.241e+01
# Epoch 240    / 2000   - loss = 8.287e+01 - val loss = 1.136e+02
# Epoch 241    / 2000   - loss = 8.344e+01 - val loss = 8.681e+01
# Epoch 242    / 2000   - loss = 8.716e+01 - val loss = 7.481e+01
# Epoch 243    / 2000   - loss = 8.130e+01 - val loss = 9.013e+01
# Epoch 244    / 2000   - loss = 1.028e+02 - val loss = 7.222e+01
# Epoch 245    / 2000   - loss = 8.084e+01 - val loss = 9.049e+01
# Epoch 246    / 2000   - loss = 7.445e+01 - val loss = 7.880e+01
# Epoch 247    / 2000   - loss = 8.507e+01 - val loss = 7.914e+01
# Epoch 248    / 2000   - loss = 1.063e+02 - val loss = 8.804e+01
# Epoch 249    / 2000   - loss = 8.634e+01 - val loss = 8.229e+01
# Epoch 250    / 2000   - loss = 7.847e+01 - val loss = 8.257e+01
# Epoch 251    / 2000   - loss = 6.843e+01 - val loss = 9.028e+01
# Epoch 252    / 2000   - loss = 8.682e+01 - val loss = 9.304e+01
# Epoch 253    / 2000   - loss = 8.013e+01 - val loss = 7.620e+01
# Epoch 254    / 2000   - loss = 8.335e+01 - val loss = 6.876e+01
# Epoch 255    / 2000   - loss = 6.128e+01 - val loss = 5.954e+01
# Epoch 256    / 2000   - loss = 8.108e+01 - val loss = 7.865e+01
# Epoch 257    / 2000   - loss = 7.334e+01 - val loss = 7.721e+01
# Epoch 258    / 2000   - loss = 1.000e+02 - val loss = 7.565e+01
# Epoch 259    / 2000   - loss = 7.741e+01 - val loss = 8.683e+01
# Epoch 260    / 2000   - loss = 7.172e+01 - val loss = 7.461e+01
# Epoch 261    / 2000   - loss = 9.330e+01 - val loss = 8.323e+01
# Epoch 262    / 2000   - loss = 7.305e+01 - val loss = 7.816e+01
# Epoch 263    / 2000   - loss = 9.590e+01 - val loss = 7.199e+01
# Epoch 264    / 2000   - loss = 8.137e+01 - val loss = 8.170e+01
# Epoch 265    / 2000   - loss = 7.021e+01 - val loss = 8.952e+01
# Epoch 266    / 2000   - loss = 8.996e+01 - val loss = 6.356e+01
# Epoch 267    / 2000   - loss = 7.265e+01 - val loss = 7.436e+01
# Epoch 268    / 2000   - loss = 6.231e+01 - val loss = 6.944e+01
# Epoch 269    / 2000   - loss = 6.934e+01 - val loss = 8.762e+01
# Epoch 270    / 2000   - loss = 7.357e+01 - val loss = 7.592e+01
# Epoch 271    / 2000   - loss = 6.414e+01 - val loss = 8.453e+01
# Epoch 272    / 2000   - loss = 1.058e+02 - val loss = 7.143e+01
# Epoch 273    / 2000   - loss = 5.877e+01 - val loss = 7.805e+01
# Epoch 274    / 2000   - loss = 5.862e+01 - val loss = 7.246e+01
# Epoch 275    / 2000   - loss = 7.874e+01 - val loss = 6.169e+01
# Epoch 276    / 2000   - loss = 7.910e+01 - val loss = 6.719e+01
# Epoch 277    / 2000   - loss = 7.646e+01 - val loss = 6.496e+01
# Epoch 278    / 2000   - loss = 7.447e+01 - val loss = 6.758e+01
# Epoch 279    / 2000   - loss = 7.457e+01 - val loss = 6.475e+01
# Epoch 280    / 2000   - loss = 7.406e+01 - val loss = 8.293e+01
# Epoch 281    / 2000   - loss = 7.152e+01 - val loss = 6.876e+01
# Epoch 282    / 2000   - loss = 7.922e+01 - val loss = 8.718e+01
# Epoch 283    / 2000   - loss = 8.323e+01 - val loss = 8.583e+01
# Epoch 284    / 2000   - loss = 8.949e+01 - val loss = 7.081e+01
# Epoch 285    / 2000   - loss = 8.320e+01 - val loss = 6.396e+01
# Epoch 286    / 2000   - loss = 5.875e+01 - val loss = 7.102e+01
# Epoch 287    / 2000   - loss = 6.725e+01 - val loss = 7.044e+01
# Epoch 288    / 2000   - loss = 6.511e+01 - val loss = 6.246e+01
# Epoch 289    / 2000   - loss = 5.572e+01 - val loss = 5.847e+01
# Epoch 290    / 2000   - loss = 7.229e+01 - val loss = 7.107e+01
# Epoch 291    / 2000   - loss = 5.262e+01 - val loss = 6.958e+01
# Epoch 292    / 2000   - loss = 6.778e+01 - val loss = 6.097e+01
# Epoch 293    / 2000   - loss = 5.865e+01 - val loss = 4.810e+01
# Epoch 294    / 2000   - loss = 6.053e+01 - val loss = 6.501e+01
# Epoch 295    / 2000   - loss = 6.869e+01 - val loss = 6.133e+01
# Epoch 296    / 2000   - loss = 5.918e+01 - val loss = 6.252e+01
# Epoch 297    / 2000   - loss = 6.098e+01 - val loss = 5.365e+01
# Epoch 298    / 2000   - loss = 6.407e+01 - val loss = 7.578e+01
# Epoch 299    / 2000   - loss = 6.819e+01 - val loss = 5.432e+01
# Epoch 300    / 2000   - loss = 6.181e+01 - val loss = 5.947e+01
# Epoch 301    / 2000   - loss = 5.685e+01 - val loss = 5.632e+01
# Epoch 302    / 2000   - loss = 4.942e+01 - val loss = 5.685e+01
# Epoch 303    / 2000   - loss = 5.322e+01 - val loss = 6.099e+01
# Epoch 304    / 2000   - loss = 6.214e+01 - val loss = 6.332e+01
# Epoch 305    / 2000   - loss = 5.680e+01 - val loss = 6.544e+01
# Epoch 306    / 2000   - loss = 7.743e+01 - val loss = 7.903e+01
# Epoch 307    / 2000   - loss = 6.094e+01 - val loss = 5.200e+01
# Epoch 308    / 2000   - loss = 6.997e+01 - val loss = 5.561e+01
# Epoch 309    / 2000   - loss = 5.623e+01 - val loss = 6.222e+01
# Epoch 310    / 2000   - loss = 5.799e+01 - val loss = 6.338e+01
# Epoch 311    / 2000   - loss = 6.690e+01 - val loss = 5.025e+01
# Epoch 312    / 2000   - loss = 6.139e+01 - val loss = 6.954e+01
# Epoch 313    / 2000   - loss = 6.347e+01 - val loss = 5.482e+01
# Epoch 314    / 2000   - loss = 5.510e+01 - val loss = 5.610e+01
# Epoch 315    / 2000   - loss = 5.720e+01 - val loss = 6.699e+01
# Epoch 316    / 2000   - loss = 6.638e+01 - val loss = 5.539e+01
# Epoch 317    / 2000   - loss = 6.897e+01 - val loss = 5.268e+01
# Epoch 318    / 2000   - loss = 5.716e+01 - val loss = 6.259e+01
# Epoch 319    / 2000   - loss = 5.279e+01 - val loss = 6.006e+01
# Epoch 320    / 2000   - loss = 6.440e+01 - val loss = 5.514e+01
# Epoch 321    / 2000   - loss = 5.882e+01 - val loss = 6.661e+01
# Epoch 322    / 2000   - loss = 5.870e+01 - val loss = 5.294e+01
# Epoch 323    / 2000   - loss = 5.953e+01 - val loss = 5.633e+01
# Epoch 324    / 2000   - loss = 4.989e+01 - val loss = 5.923e+01
# Epoch 325    / 2000   - loss = 5.828e+01 - val loss = 5.962e+01
# Epoch 326    / 2000   - loss = 4.374e+01 - val loss = 4.837e+01
# Epoch 327    / 2000   - loss = 6.078e+01 - val loss = 5.030e+01
# Epoch 328    / 2000   - loss = 5.666e+01 - val loss = 5.610e+01
# Epoch 329    / 2000   - loss = 5.743e+01 - val loss = 5.279e+01
# Epoch 330    / 2000   - loss = 5.335e+01 - val loss = 5.614e+01
# Epoch 331    / 2000   - loss = 5.286e+01 - val loss = 5.305e+01
# Epoch 332    / 2000   - loss = 6.588e+01 - val loss = 5.022e+01
# Epoch 333    / 2000   - loss = 5.358e+01 - val loss = 4.628e+01
# Epoch 334    / 2000   - loss = 5.450e+01 - val loss = 5.738e+01
# Epoch 335    / 2000   - loss = 5.183e+01 - val loss = 5.356e+01
# Epoch 336    / 2000   - loss = 5.042e+01 - val loss = 5.938e+01
# Epoch 337    / 2000   - loss = 5.326e+01 - val loss = 5.655e+01
# Epoch 338    / 2000   - loss = 5.966e+01 - val loss = 5.031e+01
# Epoch 339    / 2000   - loss = 5.179e+01 - val loss = 4.901e+01
# Epoch 340    / 2000   - loss = 5.272e+01 - val loss = 5.202e+01
# Epoch 341    / 2000   - loss = 6.559e+01 - val loss = 5.096e+01
# Epoch 342    / 2000   - loss = 5.653e+01 - val loss = 4.599e+01
# Epoch 343    / 2000   - loss = 5.068e+01 - val loss = 4.730e+01
# Epoch 344    / 2000   - loss = 4.327e+01 - val loss = 4.945e+01
# Epoch 345    / 2000   - loss = 4.388e+01 - val loss = 5.048e+01
# Epoch 346    / 2000   - loss = 4.489e+01 - val loss = 5.300e+01
# Epoch 347    / 2000   - loss = 4.737e+01 - val loss = 4.535e+01
# Epoch 348    / 2000   - loss = 5.215e+01 - val loss = 5.009e+01
# Epoch 349    / 2000   - loss = 4.585e+01 - val loss = 4.430e+01
# Epoch 350    / 2000   - loss = 4.772e+01 - val loss = 4.588e+01
# Epoch 351    / 2000   - loss = 5.256e+01 - val loss = 4.374e+01
# Epoch 352    / 2000   - loss = 6.629e+01 - val loss = 5.096e+01
# Epoch 353    / 2000   - loss = 4.318e+01 - val loss = 4.328e+01
# Epoch 354    / 2000   - loss = 4.855e+01 - val loss = 3.874e+01
# Epoch 355    / 2000   - loss = 4.699e+01 - val loss = 5.148e+01
# Epoch 356    / 2000   - loss = 5.161e+01 - val loss = 4.695e+01
# Epoch 357    / 2000   - loss = 4.801e+01 - val loss = 4.359e+01
# Epoch 358    / 2000   - loss = 3.491e+01 - val loss = 4.177e+01
# Epoch 359    / 2000   - loss = 4.440e+01 - val loss = 4.540e+01
# Epoch 360    / 2000   - loss = 4.069e+01 - val loss = 5.115e+01
# Epoch 361    / 2000   - loss = 3.967e+01 - val loss = 5.213e+01
# Epoch 362    / 2000   - loss = 4.940e+01 - val loss = 4.615e+01
# Epoch 363    / 2000   - loss = 5.009e+01 - val loss = 4.224e+01
# Epoch 364    / 2000   - loss = 4.795e+01 - val loss = 4.367e+01
# Epoch 365    / 2000   - loss = 4.206e+01 - val loss = 4.788e+01
# Epoch 366    / 2000   - loss = 4.719e+01 - val loss = 4.877e+01
# Epoch 367    / 2000   - loss = 4.789e+01 - val loss = 4.762e+01
# Epoch 368    / 2000   - loss = 3.956e+01 - val loss = 4.039e+01
# Epoch 369    / 2000   - loss = 4.156e+01 - val loss = 4.387e+01
# Epoch 370    / 2000   - loss = 4.300e+01 - val loss = 5.197e+01
# Epoch 371    / 2000   - loss = 4.078e+01 - val loss = 3.890e+01
# Epoch 372    / 2000   - loss = 4.584e+01 - val loss = 3.949e+01
# Epoch 373    / 2000   - loss = 3.332e+01 - val loss = 4.982e+01
# Epoch 374    / 2000   - loss = 4.386e+01 - val loss = 3.820e+01
# Epoch 375    / 2000   - loss = 4.299e+01 - val loss = 4.395e+01
# Epoch 376    / 2000   - loss = 3.987e+01 - val loss = 3.263e+01
# Epoch 377    / 2000   - loss = 5.038e+01 - val loss = 4.592e+01
# Epoch 378    / 2000   - loss = 4.533e+01 - val loss = 3.888e+01
# Epoch 379    / 2000   - loss = 4.227e+01 - val loss = 4.894e+01
# Epoch 380    / 2000   - loss = 3.508e+01 - val loss = 4.103e+01
# Epoch 381    / 2000   - loss = 3.640e+01 - val loss = 3.376e+01
# Epoch 382    / 2000   - loss = 5.028e+01 - val loss = 3.732e+01
# Epoch 383    / 2000   - loss = 3.316e+01 - val loss = 3.530e+01
# Epoch 384    / 2000   - loss = 3.794e+01 - val loss = 4.942e+01
# Epoch 385    / 2000   - loss = 4.008e+01 - val loss = 3.920e+01
# Epoch 386    / 2000   - loss = 4.386e+01 - val loss = 4.301e+01
# Epoch 387    / 2000   - loss = 4.066e+01 - val loss = 4.756e+01
# Epoch 388    / 2000   - loss = 4.315e+01 - val loss = 4.016e+01
# Epoch 389    / 2000   - loss = 4.431e+01 - val loss = 4.028e+01
# Epoch 390    / 2000   - loss = 3.933e+01 - val loss = 3.342e+01
# Epoch 391    / 2000   - loss = 4.469e+01 - val loss = 3.396e+01
# Epoch 392    / 2000   - loss = 3.884e+01 - val loss = 4.056e+01
# Epoch 393    / 2000   - loss = 4.312e+01 - val loss = 3.769e+01
# Epoch 394    / 2000   - loss = 4.264e+01 - val loss = 4.653e+01
# Epoch 395    / 2000   - loss = 4.011e+01 - val loss = 4.164e+01
# Epoch 396    / 2000   - loss = 3.637e+01 - val loss = 2.959e+01
# Epoch 397    / 2000   - loss = 4.552e+01 - val loss = 3.974e+01
# Epoch 398    / 2000   - loss = 3.328e+01 - val loss = 3.625e+01
# Epoch 399    / 2000   - loss = 5.059e+01 - val loss = 3.345e+01
# Epoch 400    / 2000   - loss = 3.575e+01 - val loss = 2.798e+01
# Epoch 401    / 2000   - loss = 3.332e+01 - val loss = 4.338e+01
# Epoch 402    / 2000   - loss = 4.089e+01 - val loss = 4.525e+01
# Epoch 403    / 2000   - loss = 3.744e+01 - val loss = 3.552e+01
# Epoch 404    / 2000   - loss = 3.349e+01 - val loss = 2.831e+01
# Epoch 405    / 2000   - loss = 4.066e+01 - val loss = 3.530e+01
# Epoch 406    / 2000   - loss = 4.116e+01 - val loss = 3.701e+01
# Epoch 407    / 2000   - loss = 3.655e+01 - val loss = 3.345e+01
# Epoch 408    / 2000   - loss = 3.752e+01 - val loss = 3.762e+01
# Epoch 409    / 2000   - loss = 3.108e+01 - val loss = 3.337e+01
# Epoch 410    / 2000   - loss = 3.058e+01 - val loss = 3.830e+01
# Epoch 411    / 2000   - loss = 3.500e+01 - val loss = 3.006e+01
# Epoch 412    / 2000   - loss = 4.821e+01 - val loss = 3.325e+01
# Epoch 413    / 2000   - loss = 4.064e+01 - val loss = 4.079e+01
# Epoch 414    / 2000   - loss = 4.728e+01 - val loss = 3.669e+01
# Epoch 415    / 2000   - loss = 3.251e+01 - val loss = 3.536e+01
# Epoch 416    / 2000   - loss = 3.507e+01 - val loss = 4.126e+01
# Epoch 417    / 2000   - loss = 3.236e+01 - val loss = 4.391e+01
# Epoch 418    / 2000   - loss = 3.581e+01 - val loss = 3.877e+01
# Epoch 419    / 2000   - loss = 4.143e+01 - val loss = 3.823e+01
# Epoch 420    / 2000   - loss = 3.334e+01 - val loss = 3.464e+01
# Epoch 421    / 2000   - loss = 3.591e+01 - val loss = 4.270e+01
# Epoch 422    / 2000   - loss = 3.805e+01 - val loss = 3.650e+01
# Epoch 423    / 2000   - loss = 2.973e+01 - val loss = 3.733e+01
# Epoch 424    / 2000   - loss = 4.186e+01 - val loss = 3.275e+01
# Epoch 425    / 2000   - loss = 3.365e+01 - val loss = 3.266e+01
# Epoch 426    / 2000   - loss = 3.135e+01 - val loss = 3.565e+01
# Epoch 427    / 2000   - loss = 3.333e+01 - val loss = 3.059e+01
# Epoch 428    / 2000   - loss = 2.863e+01 - val loss = 2.722e+01
# Epoch 429    / 2000   - loss = 3.125e+01 - val loss = 4.382e+01
# Epoch 430    / 2000   - loss = 3.398e+01 - val loss = 2.695e+01
# Epoch 431    / 2000   - loss = 2.832e+01 - val loss = 2.411e+01
# Epoch 432    / 2000   - loss = 2.795e+01 - val loss = 3.221e+01
# Epoch 433    / 2000   - loss = 2.929e+01 - val loss = 3.676e+01
# Epoch 434    / 2000   - loss = 3.308e+01 - val loss = 3.906e+01
# Epoch 435    / 2000   - loss = 3.419e+01 - val loss = 3.531e+01
# Epoch 436    / 2000   - loss = 3.348e+01 - val loss = 3.669e+01
# Epoch 437    / 2000   - loss = 2.883e+01 - val loss = 2.070e+01
# Epoch 438    / 2000   - loss = 3.427e+01 - val loss = 3.124e+01
# Epoch 439    / 2000   - loss = 2.476e+01 - val loss = 2.590e+01
# Epoch 440    / 2000   - loss = 3.700e+01 - val loss = 3.581e+01
# Epoch 441    / 2000   - loss = 3.082e+01 - val loss = 3.190e+01
# Epoch 442    / 2000   - loss = 3.602e+01 - val loss = 2.538e+01
# Epoch 443    / 2000   - loss = 3.550e+01 - val loss = 3.371e+01
# Epoch 444    / 2000   - loss = 2.317e+01 - val loss = 3.309e+01
# Epoch 445    / 2000   - loss = 2.921e+01 - val loss = 3.021e+01
# Epoch 446    / 2000   - loss = 3.013e+01 - val loss = 2.822e+01
# Epoch 447    / 2000   - loss = 2.416e+01 - val loss = 3.423e+01
# Epoch 448    / 2000   - loss = 3.436e+01 - val loss = 3.010e+01
# Epoch 449    / 2000   - loss = 2.483e+01 - val loss = 2.939e+01
# Epoch 450    / 2000   - loss = 3.411e+01 - val loss = 3.542e+01
# Epoch 451    / 2000   - loss = 3.242e+01 - val loss = 3.714e+01
# Epoch 452    / 2000   - loss = 3.046e+01 - val loss = 2.929e+01
# Epoch 453    / 2000   - loss = 3.031e+01 - val loss = 2.632e+01
# Epoch 454    / 2000   - loss = 2.494e+01 - val loss = 2.894e+01
# Epoch 455    / 2000   - loss = 2.914e+01 - val loss = 3.081e+01
# Epoch 456    / 2000   - loss = 3.439e+01 - val loss = 3.197e+01
# Epoch 457    / 2000   - loss = 3.427e+01 - val loss = 3.380e+01
# Epoch 458    / 2000   - loss = 2.844e+01 - val loss = 3.015e+01
# Epoch 459    / 2000   - loss = 3.240e+01 - val loss = 2.345e+01
# Epoch 460    / 2000   - loss = 2.664e+01 - val loss = 2.913e+01
# Epoch 461    / 2000   - loss = 2.598e+01 - val loss = 3.067e+01
# Epoch 462    / 2000   - loss = 2.439e+01 - val loss = 2.690e+01
# Epoch 463    / 2000   - loss = 2.344e+01 - val loss = 2.185e+01
# Epoch 464    / 2000   - loss = 2.947e+01 - val loss = 2.180e+01
# Epoch 465    / 2000   - loss = 3.127e+01 - val loss = 2.984e+01
# Epoch 466    / 2000   - loss = 2.378e+01 - val loss = 3.357e+01
# Epoch 467    / 2000   - loss = 2.662e+01 - val loss = 2.290e+01
# Epoch 468    / 2000   - loss = 2.705e+01 - val loss = 3.010e+01
# Epoch 469    / 2000   - loss = 2.992e+01 - val loss = 3.063e+01
# Epoch 470    / 2000   - loss = 2.340e+01 - val loss = 2.213e+01
# Epoch 471    / 2000   - loss = 2.518e+01 - val loss = 3.198e+01
# Epoch 472    / 2000   - loss = 2.970e+01 - val loss = 2.828e+01
# Epoch 473    / 2000   - loss = 2.892e+01 - val loss = 2.723e+01
# Epoch 474    / 2000   - loss = 3.503e+01 - val loss = 3.266e+01
# Epoch 475    / 2000   - loss = 2.746e+01 - val loss = 2.752e+01
# Epoch 476    / 2000   - loss = 1.948e+01 - val loss = 1.846e+01
# Epoch 477    / 2000   - loss = 2.128e+01 - val loss = 2.237e+01
# Epoch 478    / 2000   - loss = 3.268e+01 - val loss = 2.751e+01
# Epoch 479    / 2000   - loss = 3.294e+01 - val loss = 1.944e+01
# Epoch 480    / 2000   - loss = 2.743e+01 - val loss = 2.451e+01
# Epoch 481    / 2000   - loss = 3.263e+01 - val loss = 3.150e+01
# Epoch 482    / 2000   - loss = 2.786e+01 - val loss = 2.903e+01
# Epoch 483    / 2000   - loss = 1.876e+01 - val loss = 2.768e+01
# Epoch 484    / 2000   - loss = 2.999e+01 - val loss = 2.496e+01
# Epoch 485    / 2000   - loss = 3.105e+01 - val loss = 2.391e+01
# Epoch 486    / 2000   - loss = 2.535e+01 - val loss = 2.372e+01
# Epoch 487    / 2000   - loss = 2.955e+01 - val loss = 2.424e+01
# Epoch 488    / 2000   - loss = 2.932e+01 - val loss = 2.342e+01
# Epoch 489    / 2000   - loss = 2.345e+01 - val loss = 2.276e+01
# Epoch 490    / 2000   - loss = 2.110e+01 - val loss = 2.861e+01
# Epoch 491    / 2000   - loss = 1.626e+01 - val loss = 2.168e+01
# Epoch 492    / 2000   - loss = 1.866e+01 - val loss = 2.775e+01
# Epoch 493    / 2000   - loss = 2.555e+01 - val loss = 2.864e+01
# Epoch 494    / 2000   - loss = 2.318e+01 - val loss = 2.446e+01
# Epoch 495    / 2000   - loss = 2.451e+01 - val loss = 2.424e+01
# Epoch 496    / 2000   - loss = 2.737e+01 - val loss = 2.181e+01
# Epoch 497    / 2000   - loss = 1.741e+01 - val loss = 2.240e+01
# Epoch 498    / 2000   - loss = 2.538e+01 - val loss = 1.938e+01
# Epoch 499    / 2000   - loss = 2.177e+01 - val loss = 1.927e+01
# Epoch 500    / 2000   - loss = 3.165e+01 - val loss = 2.056e+01
# Epoch 501    / 2000   - loss = 2.204e+01 - val loss = 2.433e+01
# Epoch 502    / 2000   - loss = 2.088e+01 - val loss = 2.618e+01
# Epoch 503    / 2000   - loss = 2.613e+01 - val loss = 2.592e+01
# Epoch 504    / 2000   - loss = 2.157e+01 - val loss = 2.826e+01
# Epoch 505    / 2000   - loss = 2.342e+01 - val loss = 2.244e+01
# Epoch 506    / 2000   - loss = 2.007e+01 - val loss = 1.952e+01
# Epoch 507    / 2000   - loss = 2.537e+01 - val loss = 2.388e+01
# Epoch 508    / 2000   - loss = 2.076e+01 - val loss = 1.264e+01
# Epoch 509    / 2000   - loss = 1.776e+01 - val loss = 2.331e+01
# Epoch 510    / 2000   - loss = 1.948e+01 - val loss = 2.476e+01
# Epoch 511    / 2000   - loss = 2.877e+01 - val loss = 3.272e+01
# Epoch 512    / 2000   - loss = 2.258e+01 - val loss = 2.675e+01
# Epoch 513    / 2000   - loss = 2.439e+01 - val loss = 2.396e+01
# Epoch 514    / 2000   - loss = 2.551e+01 - val loss = 2.040e+01
# Epoch 515    / 2000   - loss = 2.036e+01 - val loss = 1.710e+01
# Epoch 516    / 2000   - loss = 1.732e+01 - val loss = 3.030e+01
# Epoch 517    / 2000   - loss = 2.185e+01 - val loss = 2.216e+01
# Epoch 518    / 2000   - loss = 2.623e+01 - val loss = 1.827e+01
# Epoch 519    / 2000   - loss = 1.749e+01 - val loss = 2.349e+01
# Epoch 520    / 2000   - loss = 1.568e+01 - val loss = 2.272e+01
# Epoch 521    / 2000   - loss = 2.133e+01 - val loss = 2.470e+01
# Epoch 522    / 2000   - loss = 1.546e+01 - val loss = 1.516e+01
# Epoch 523    / 2000   - loss = 1.673e+01 - val loss = 1.725e+01
# Epoch 524    / 2000   - loss = 1.489e+01 - val loss = 2.055e+01
# Epoch 525    / 2000   - loss = 2.307e+01 - val loss = 2.529e+01
# Epoch 526    / 2000   - loss = 2.333e+01 - val loss = 1.498e+01
# Epoch 527    / 2000   - loss = 2.003e+01 - val loss = 2.198e+01
# Epoch 528    / 2000   - loss = 2.192e+01 - val loss = 1.606e+01
# Epoch 529    / 2000   - loss = 1.972e+01 - val loss = 2.051e+01
# Epoch 530    / 2000   - loss = 2.246e+01 - val loss = 2.472e+01
# Epoch 531    / 2000   - loss = 2.034e+01 - val loss = 1.733e+01
# Epoch 532    / 2000   - loss = 2.169e+01 - val loss = 1.948e+01
# Epoch 533    / 2000   - loss = 2.733e+01 - val loss = 2.156e+01
# Epoch 534    / 2000   - loss = 2.051e+01 - val loss = 1.868e+01
# Epoch 535    / 2000   - loss = 1.657e+01 - val loss = 1.418e+01
# Epoch 536    / 2000   - loss = 2.326e+01 - val loss = 1.930e+01
# Epoch 537    / 2000   - loss = 1.640e+01 - val loss = 1.662e+01
# Epoch 538    / 2000   - loss = 1.971e+01 - val loss = 1.718e+01
# Epoch 539    / 2000   - loss = 1.768e+01 - val loss = 1.565e+01
# Epoch 540    / 2000   - loss = 2.610e+01 - val loss = 1.810e+01
# Epoch 541    / 2000   - loss = 1.582e+01 - val loss = 1.002e+01
# Epoch 542    / 2000   - loss = 1.825e+01 - val loss = 1.646e+01
# Epoch 543    / 2000   - loss = 2.398e+01 - val loss = 1.350e+01
# Epoch 544    / 2000   - loss = 1.677e+01 - val loss = 2.349e+01
# Epoch 545    / 2000   - loss = 1.515e+01 - val loss = 1.748e+01
# Epoch 546    / 2000   - loss = 1.497e+01 - val loss = 1.733e+01
# Epoch 547    / 2000   - loss = 2.229e+01 - val loss = 1.879e+01
# Epoch 548    / 2000   - loss = 9.559e+00 - val loss = 1.404e+01
# Epoch 549    / 2000   - loss = 1.450e+01 - val loss = 1.792e+01
# Epoch 550    / 2000   - loss = 1.696e+01 - val loss = 1.239e+01
# Epoch 551    / 2000   - loss = 1.664e+01 - val loss = 1.523e+01
# Epoch 552    / 2000   - loss = 1.762e+01 - val loss = 1.668e+01
# Epoch 553    / 2000   - loss = 1.461e+01 - val loss = 1.401e+01
# Epoch 554    / 2000   - loss = 2.338e+01 - val loss = 2.401e+01
# Epoch 555    / 2000   - loss = 1.988e+01 - val loss = 1.803e+01
# Epoch 556    / 2000   - loss = 2.476e+01 - val loss = 1.502e+01
# Epoch 557    / 2000   - loss = 1.282e+01 - val loss = 1.731e+01
# Epoch 558    / 2000   - loss = 1.954e+01 - val loss = 1.037e+01
# Epoch 559    / 2000   - loss = 1.367e+01 - val loss = 1.588e+01
# Epoch 560    / 2000   - loss = 1.599e+01 - val loss = 1.484e+01
# Epoch 561    / 2000   - loss = 1.365e+01 - val loss = 1.853e+01
# Epoch 562    / 2000   - loss = 2.108e+01 - val loss = 1.500e+01
# Epoch 563    / 2000   - loss = 1.539e+01 - val loss = 2.603e+01
# Epoch 564    / 2000   - loss = 1.705e+01 - val loss = 1.606e+01
# Epoch 565    / 2000   - loss = 1.682e+01 - val loss = 1.527e+01
# Epoch 566    / 2000   - loss = 9.217e+00 - val loss = 1.479e+01
# Epoch 567    / 2000   - loss = 1.056e+01 - val loss = 1.529e+01
# Epoch 568    / 2000   - loss = 1.010e+01 - val loss = 1.950e+01
# Epoch 569    / 2000   - loss = 9.515e+00 - val loss = 1.772e+01
# Epoch 570    / 2000   - loss = 1.160e+01 - val loss = 2.102e+01
# Epoch 571    / 2000   - loss = 7.495e+00 - val loss = 1.812e+01
# Epoch 572    / 2000   - loss = 1.191e+01 - val loss = 1.578e+01
# Epoch 573    / 2000   - loss = 1.467e+01 - val loss = 1.691e+01
# Epoch 574    / 2000   - loss = 1.353e+01 - val loss = 1.842e+01
# Epoch 575    / 2000   - loss = 1.470e+01 - val loss = 1.047e+01
# Epoch 576    / 2000   - loss = 1.429e+01 - val loss = 1.812e+01
# Epoch 577    / 2000   - loss = 1.177e+01 - val loss = 1.623e+01
# Epoch 578    / 2000   - loss = 1.286e+01 - val loss = 1.408e+01
# Epoch 579    / 2000   - loss = 1.489e+01 - val loss = 1.661e+01
# Epoch 580    / 2000   - loss = 1.674e+01 - val loss = 8.383e+00
# Epoch 581    / 2000   - loss = 1.415e+01 - val loss = 9.566e+00
# Epoch 582    / 2000   - loss = 1.648e+01 - val loss = 1.642e+01
# Epoch 583    / 2000   - loss = 1.588e+01 - val loss = 1.970e+01
# Epoch 584    / 2000   - loss = 1.722e+01 - val loss = 1.454e+01
# Epoch 585    / 2000   - loss = 7.496e+00 - val loss = 1.434e+01
# Epoch 586    / 2000   - loss = 6.070e+00 - val loss = 1.435e+01
# Epoch 587    / 2000   - loss = 1.571e+01 - val loss = 1.248e+01
# Epoch 588    / 2000   - loss = 1.535e+01 - val loss = 1.170e+01
# Epoch 589    / 2000   - loss = 1.405e+01 - val loss = 9.992e+00
# Epoch 590    / 2000   - loss = 1.572e+01 - val loss = 1.032e+01
# Epoch 591    / 2000   - loss = 1.005e+01 - val loss = 1.482e+01
# Epoch 592    / 2000   - loss = 1.359e+01 - val loss = 1.737e+01
# Epoch 593    / 2000   - loss = 8.599e+00 - val loss = 1.498e+01
# Epoch 594    / 2000   - loss = 1.387e+01 - val loss = 9.896e+00
# Epoch 595    / 2000   - loss = 1.168e+01 - val loss = 8.246e+00
# Epoch 596    / 2000   - loss = 7.874e+00 - val loss = 1.115e+01
# Epoch 597    / 2000   - loss = 7.875e+00 - val loss = 1.457e+01
# Epoch 598    / 2000   - loss = 8.828e+00 - val loss = 1.279e+01
# Epoch 599    / 2000   - loss = 8.973e+00 - val loss = 1.140e+01
# Epoch 600    / 2000   - loss = 1.569e+01 - val loss = 1.165e+01
# Epoch 601    / 2000   - loss = 7.904e+00 - val loss = 7.231e+00
# Epoch 602    / 2000   - loss = 1.606e+01 - val loss = 1.195e+01
# Epoch 603    / 2000   - loss = 3.431e+00 - val loss = 9.782e+00
# Epoch 604    / 2000   - loss = 7.408e+00 - val loss = 1.092e+01
# Epoch 605    / 2000   - loss = 7.507e+00 - val loss = 9.455e+00
# Epoch 606    / 2000   - loss = 1.125e+01 - val loss = 9.002e+00
# Epoch 607    / 2000   - loss = 1.320e+01 - val loss = 9.361e+00
# Epoch 608    / 2000   - loss = 1.558e+01 - val loss = 1.319e+01
# Epoch 609    / 2000   - loss = 7.155e+00 - val loss = 1.896e+00
# Epoch 610    / 2000   - loss = 1.083e+01 - val loss = 1.050e+01
# Epoch 611    / 2000   - loss = 1.374e+01 - val loss = 8.587e+00
# Epoch 612    / 2000   - loss = 8.559e+00 - val loss = 1.130e+01
# Epoch 613    / 2000   - loss = 7.848e+00 - val loss = 1.110e+01
# Epoch 614    / 2000   - loss = 9.328e+00 - val loss = 8.671e+00
# Epoch 615    / 2000   - loss = 8.850e+00 - val loss = 1.362e+01
# Epoch 616    / 2000   - loss = 6.827e+00 - val loss = 1.172e+01
# Epoch 617    / 2000   - loss = 6.636e+00 - val loss = 6.707e+00
# Epoch 618    / 2000   - loss = 5.583e+00 - val loss = 5.327e+00
# Epoch 619    / 2000   - loss = 1.184e+01 - val loss = 1.311e+01
# Epoch 620    / 2000   - loss = 7.296e+00 - val loss = 1.035e+01
# Epoch 621    / 2000   - loss = 8.365e+00 - val loss = 1.350e+01
# Epoch 622    / 2000   - loss = 7.369e+00 - val loss = 1.254e+01
# Epoch 623    / 2000   - loss = 1.232e+01 - val loss = 1.478e+01
# Epoch 624    / 2000   - loss = 9.812e+00 - val loss = 1.095e+01
# Epoch 625    / 2000   - loss = 8.438e+00 - val loss = 5.566e+00
# Epoch 626    / 2000   - loss = 1.595e+01 - val loss = 6.188e+00
# Epoch 627    / 2000   - loss = 1.413e+01 - val loss = 1.030e+01
# Epoch 628    / 2000   - loss = 1.083e+00 - val loss = 1.715e+01
# Epoch 629    / 2000   - loss = 1.419e+01 - val loss = 6.951e+00
# Epoch 630    / 2000   - loss = 7.413e+00 - val loss = 8.094e+00
# Epoch 631    / 2000   - loss = 5.042e+00 - val loss = 5.212e+00
# Epoch 632    / 2000   - loss = 4.621e+00 - val loss = 7.006e+00
# Epoch 633    / 2000   - loss = 6.785e+00 - val loss = 1.167e+01
# Epoch 634    / 2000   - loss = 1.201e+01 - val loss = 1.446e+00
# Epoch 635    / 2000   - loss = 1.313e+01 - val loss = 1.118e+01
# Epoch 636    / 2000   - loss = 9.904e+00 - val loss = 5.319e+00
# Epoch 637    / 2000   - loss = 4.768e+00 - val loss = -3.016e-01
# Epoch 638    / 2000   - loss = 1.108e+01 - val loss = 6.190e+00
# Epoch 639    / 2000   - loss = 1.021e+01 - val loss = 4.185e+00
# Epoch 640    / 2000   - loss = 1.299e+01 - val loss = 4.885e+00
# Epoch 641    / 2000   - loss = 1.387e+01 - val loss = 5.947e+00
# Epoch 642    / 2000   - loss = 1.114e+01 - val loss = 9.490e+00
# Epoch 643    / 2000   - loss = 5.935e+00 - val loss = -1.145e+00
# Epoch 644    / 2000   - loss = 8.468e+00 - val loss = 6.829e+00
# Epoch 645    / 2000   - loss = 1.040e+01 - val loss = 6.907e+00
# Epoch 646    / 2000   - loss = 7.256e+00 - val loss = 5.233e+00
# Epoch 647    / 2000   - loss = 2.525e+00 - val loss = 7.394e+00
# Epoch 648    / 2000   - loss = 6.758e+00 - val loss = -3.271e+00
# Epoch 649    / 2000   - loss = 6.284e+00 - val loss = 5.050e+00
# Epoch 650    / 2000   - loss = 5.402e+00 - val loss = 1.944e+00
# Epoch 651    / 2000   - loss = 4.147e+00 - val loss = 4.724e+00
# Epoch 652    / 2000   - loss = 9.049e+00 - val loss = 1.022e+01
# Epoch 653    / 2000   - loss = 3.447e+00 - val loss = 4.860e+00
# Epoch 654    / 2000   - loss = 4.394e+00 - val loss = 4.570e+00
# Epoch 655    / 2000   - loss = 6.089e+00 - val loss = 7.943e+00
# Epoch 656    / 2000   - loss = 6.584e+00 - val loss = 3.491e+00
# Epoch 657    / 2000   - loss = -1.308e+00 - val loss = 3.495e+00
# Epoch 658    / 2000   - loss = 3.055e+00 - val loss = -1.198e+00
# Epoch 659    / 2000   - loss = 3.939e+00 - val loss = 3.611e+00
# Epoch 660    / 2000   - loss = 2.036e+00 - val loss = 7.616e-01
# Epoch 661    / 2000   - loss = 7.718e+00 - val loss = 6.156e+00
# Epoch 662    / 2000   - loss = 3.237e+00 - val loss = 5.353e+00
# Epoch 663    / 2000   - loss = 4.404e+00 - val loss = 4.474e-01
# Epoch 664    / 2000   - loss = 8.540e+00 - val loss = 7.742e+00
# Epoch 665    / 2000   - loss = 4.646e+00 - val loss = 5.144e+00
# Epoch 666    / 2000   - loss = 8.275e-01 - val loss = 5.651e+00
# Epoch 667    / 2000   - loss = 4.498e+00 - val loss = -7.047e-01
# Epoch 668    / 2000   - loss = 7.876e+00 - val loss = 4.306e+00
# Epoch 669    / 2000   - loss = 1.980e+00 - val loss = -1.118e+00
# Epoch 670    / 2000   - loss = 2.040e+00 - val loss = 5.456e+00
# Epoch 671    / 2000   - loss = -1.452e+00 - val loss = 2.961e-01
# Epoch 672    / 2000   - loss = 6.031e+00 - val loss = 2.110e+00
# Epoch 673    / 2000   - loss = 6.825e+00 - val loss = 5.001e+00
# Epoch 674    / 2000   - loss = 7.029e+00 - val loss = 2.314e+00
# Epoch 675    / 2000   - loss = 4.492e+00 - val loss = 5.701e+00
# Epoch 676    / 2000   - loss = -2.183e-01 - val loss = 3.220e+00
# Epoch 677    / 2000   - loss = 3.143e+00 - val loss = 2.187e-01
# Epoch 678    / 2000   - loss = 6.148e+00 - val loss = 5.711e+00
# Epoch 679    / 2000   - loss = 2.295e+00 - val loss = 5.855e+00
# Epoch 680    / 2000   - loss = 2.063e+00 - val loss = 2.602e+00
# Epoch 681    / 2000   - loss = 1.216e+00 - val loss = 8.583e-02
# Epoch 682    / 2000   - loss = -3.300e+00 - val loss = 8.916e+00
# Epoch 683    / 2000   - loss = 3.555e-01 - val loss = 2.405e+00
# Epoch 684    / 2000   - loss = 1.541e+01 - val loss = -7.420e-01
# Epoch 685    / 2000   - loss = 5.201e+00 - val loss = 8.361e-01
# Epoch 686    / 2000   - loss = 3.822e+00 - val loss = 2.732e+00
# Epoch 687    / 2000   - loss = -2.035e+00 - val loss = 4.392e+00
# Epoch 688    / 2000   - loss = -6.300e+00 - val loss = 3.491e+00
# Epoch 689    / 2000   - loss = -1.751e+00 - val loss = -3.005e+00
# Epoch 690    / 2000   - loss = 2.635e+00 - val loss = 3.395e+00
# Epoch 691    / 2000   - loss = -9.524e-01 - val loss = 4.325e+00
# Epoch 692    / 2000   - loss = -1.934e+00 - val loss = -1.719e+00
# Epoch 693    / 2000   - loss = 1.746e+00 - val loss = -1.593e+00
# Epoch 694    / 2000   - loss = -5.827e+00 - val loss = -1.462e+00
# Epoch 695    / 2000   - loss = -4.492e-01 - val loss = -4.798e+00
# Epoch 696    / 2000   - loss = -3.554e+00 - val loss = -5.046e+00
# Epoch 697    / 2000   - loss = 5.666e+00 - val loss = -2.815e+00
# Epoch 698    / 2000   - loss = 5.306e+00 - val loss = 3.141e+00
# Epoch 699    / 2000   - loss = 6.990e+00 - val loss = 1.693e+00
# Epoch 700    / 2000   - loss = 2.359e+00 - val loss = 1.263e+00
# Epoch 701    / 2000   - loss = 2.029e-01 - val loss = 1.512e+00
# Epoch 702    / 2000   - loss = -3.561e-02 - val loss = 2.135e+00
# Epoch 703    / 2000   - loss = 2.080e+00 - val loss = 1.078e+00
# Epoch 704    / 2000   - loss = -1.909e+00 - val loss = 1.540e+00
# Epoch 705    / 2000   - loss = -7.089e-01 - val loss = -1.376e+00
# Epoch 706    / 2000   - loss = 4.553e+00 - val loss = 2.900e-01
# Epoch 707    / 2000   - loss = -1.883e+00 - val loss = -9.995e-02
# Epoch 708    / 2000   - loss = -3.208e+00 - val loss = -3.569e-01
# Epoch 709    / 2000   - loss = -4.267e+00 - val loss = -1.011e+00
# Epoch 710    / 2000   - loss = 2.964e+00 - val loss = -2.976e+00
# Epoch 711    / 2000   - loss = -1.197e+00 - val loss = -5.690e-01
# Epoch 712    / 2000   - loss = 1.813e+00 - val loss = -6.593e+00
# Epoch 713    / 2000   - loss = -2.393e+00 - val loss = 9.037e-01
# Epoch 714    / 2000   - loss = 2.480e+00 - val loss = -3.711e-01
# Epoch 715    / 2000   - loss = 8.192e-02 - val loss = -3.493e+00
# Epoch 716    / 2000   - loss = 3.211e-01 - val loss = -6.292e+00
# Epoch 717    / 2000   - loss = -5.353e+00 - val loss = -2.714e+00
# Epoch 718    / 2000   - loss = 4.421e-01 - val loss = -1.207e+00
# Epoch 719    / 2000   - loss = -4.751e+00 - val loss = -9.994e-02
# Epoch 720    / 2000   - loss = -1.348e+00 - val loss = -3.632e+00
# Epoch 721    / 2000   - loss = -2.305e+00 - val loss = 3.008e+00
# Epoch 722    / 2000   - loss = -1.112e+00 - val loss = -6.558e+00
# Epoch 723    / 2000   - loss = -2.538e+00 - val loss = -1.765e+00
# Epoch 724    / 2000   - loss = -4.221e-02 - val loss = -2.960e+00
# Epoch 725    / 2000   - loss = 1.282e+00 - val loss = -3.026e+00
# Epoch 726    / 2000   - loss = -7.282e+00 - val loss = -7.340e+00
# Epoch 727    / 2000   - loss = -4.250e+00 - val loss = -4.830e+00
# Epoch 728    / 2000   - loss = -2.126e+00 - val loss = -3.603e+00
# Epoch 729    / 2000   - loss = -3.595e+00 - val loss = -1.245e+00
# Epoch 730    / 2000   - loss = -5.307e+00 - val loss = -3.371e+00
# Epoch 731    / 2000   - loss = 1.684e+00 - val loss = -2.175e+00
# Epoch 732    / 2000   - loss = -2.254e+00 - val loss = 3.883e-01
# Epoch 733    / 2000   - loss = -3.943e-01 - val loss = -2.525e+00
# Epoch 734    / 2000   - loss = -3.712e+00 - val loss = -4.977e+00
# Epoch 735    / 2000   - loss = -3.299e+00 - val loss = 1.608e+00
# Epoch 736    / 2000   - loss = -3.747e+00 - val loss = -5.387e+00
# Epoch 737    / 2000   - loss = -5.687e+00 - val loss = -2.160e+00
# Epoch 738    / 2000   - loss = -6.232e-01 - val loss = -1.193e+00
# Epoch 739    / 2000   - loss = -2.496e+00 - val loss = -4.975e+00
# Epoch 740    / 2000   - loss = -4.705e+00 - val loss = -1.653e+00
# Epoch 741    / 2000   - loss = -1.244e+00 - val loss = -3.616e+00
# Epoch 742    / 2000   - loss = -2.941e+00 - val loss = -4.030e+00
# Epoch 743    / 2000   - loss = -4.741e+00 - val loss = -8.614e-01
# Epoch 744    / 2000   - loss = -6.509e+00 - val loss = -1.377e+00
# Epoch 745    / 2000   - loss = -1.933e+00 - val loss = -2.830e+00
# Epoch 746    / 2000   - loss = -1.116e+01 - val loss = -3.682e+00
# Epoch 747    / 2000   - loss = -5.519e+00 - val loss = 1.609e+00
# Epoch 748    / 2000   - loss = -4.113e+00 - val loss = -6.672e+00
# ...
# Epoch 1759   / 2000   - loss = -6.796e+01 - val loss = -6.447e+01
# Epoch 1760   / 2000   - loss = -6.660e+01 - val loss = -6.635e+01
# Epoch 1761   / 2000   - loss = -6.621e+01 - val loss = -6.676e+01
# Epoch 1762   / 2000   - loss = -6.630e+01 - val loss = -6.701e+01
# Epoch 1763   / 2000   - loss = -6.758e+01 - val loss = -6.665e+01
# Epoch 1764   / 2000   - loss = -6.708e+01 - val loss = -6.691e+01
# Epoch 1765   / 2000   - loss = -6.604e+01 - val loss = -6.704e+01
# Epoch 1766   / 2000   - loss = -6.555e+01 - val loss = -6.704e+01
# Epoch 1767   / 2000   - loss = -6.833e+01 - val loss = -6.503e+01
# Epoch 1768   / 2000   - loss = -6.474e+01 - val loss = -6.757e+01
# Epoch 1769   / 2000   - loss = -6.670e+01 - val loss = -6.771e+01
# Epoch 1770   / 2000   - loss = -6.618e+01 - val loss = -6.781e+01
# Epoch 1771   / 2000   - loss = -6.673e+01 - val loss = -6.679e+01
# Epoch 1772   / 2000   - loss = -6.605e+01 - val loss = -6.561e+01
# Epoch 1773   / 2000   - loss = -6.703e+01 - val loss = -6.658e+01
# Epoch 1774   / 2000   - loss = -6.797e+01 - val loss = -6.308e+01
# Epoch 1775   / 2000   - loss = -6.762e+01 - val loss = -6.794e+01
# Epoch 1776   / 2000   - loss = -6.738e+01 - val loss = -6.805e+01
# Epoch 1777   / 2000   - loss = -6.583e+01 - val loss = -6.748e+01
# Epoch 1778   / 2000   - loss = -6.273e+01 - val loss = -6.766e+01
# Epoch 1779   / 2000   - loss = -6.361e+01 - val loss = -6.642e+01
# Epoch 1780   / 2000   - loss = -6.444e+01 - val loss = -6.984e+01
# Epoch 1781   / 2000   - loss = -6.711e+01 - val loss = -6.637e+01
# Epoch 1782   / 2000   - loss = -6.562e+01 - val loss = -6.632e+01
# Epoch 1783   / 2000   - loss = -6.688e+01 - val loss = -6.665e+01
# Epoch 1784   / 2000   - loss = -6.732e+01 - val loss = -6.855e+01
# Epoch 1785   / 2000   - loss = -6.529e+01 - val loss = -6.586e+01
# Epoch 1786   / 2000   - loss = -6.783e+01 - val loss = -6.678e+01
# Epoch 1787   / 2000   - loss = -6.668e+01 - val loss = -6.512e+01
# Epoch 1788   / 2000   - loss = -6.612e+01 - val loss = -6.712e+01
# Epoch 1789   / 2000   - loss = -6.737e+01 - val loss = -6.846e+01
# Epoch 1790   / 2000   - loss = -6.666e+01 - val loss = -6.755e+01
# Epoch 1791   / 2000   - loss = -6.608e+01 - val loss = -6.622e+01
# Epoch 1792   / 2000   - loss = -6.769e+01 - val loss = -6.676e+01
# Epoch 1793   / 2000   - loss = -6.439e+01 - val loss = -6.482e+01
# Epoch 1794   / 2000   - loss = -6.784e+01 - val loss = -6.841e+01
# Epoch 1795   / 2000   - loss = -6.760e+01 - val loss = -6.626e+01
# Epoch 1796   / 2000   - loss = -6.685e+01 - val loss = -6.685e+01
# Epoch 1797   / 2000   - loss = -6.792e+01 - val loss = -6.530e+01
# Epoch 1798   / 2000   - loss = -6.701e+01 - val loss = -6.584e+01
# Epoch 1799   / 2000   - loss = -6.950e+01 - val loss = -6.659e+01
# Epoch 1800   / 2000   - loss = -6.571e+01 - val loss = -6.533e+01
# Epoch 1801   / 2000   - loss = -6.425e+01 - val loss = -6.818e+01
# Epoch 1802   / 2000   - loss = -6.656e+01 - val loss = -6.431e+01
# Epoch 1803   / 2000   - loss = -6.641e+01 - val loss = -6.760e+01
# Epoch 1804   / 2000   - loss = -6.503e+01 - val loss = -6.840e+01
# Epoch 1805   / 2000   - loss = -6.737e+01 - val loss = -6.612e+01
# Epoch 1806   / 2000   - loss = -6.768e+01 - val loss = -6.605e+01
# Epoch 1807   / 2000   - loss = -6.603e+01 - val loss = -6.657e+01
# Epoch 1808   / 2000   - loss = -6.526e+01 - val loss = -6.474e+01
# Epoch 1809   / 2000   - loss = -6.450e+01 - val loss = -6.815e+01
# Epoch 1810   / 2000   - loss = -6.527e+01 - val loss = -6.795e+01
# Epoch 1811   / 2000   - loss = -6.845e+01 - val loss = -6.689e+01
# Epoch 1812   / 2000   - loss = -6.685e+01 - val loss = -6.747e+01
# Epoch 1813   / 2000   - loss = -6.736e+01 - val loss = -6.834e+01
# Epoch 1814   / 2000   - loss = -6.758e+01 - val loss = -6.717e+01
# Epoch 1815   / 2000   - loss = -6.364e+01 - val loss = -6.726e+01
# Epoch 1816   / 2000   - loss = -6.689e+01 - val loss = -6.617e+01
# Epoch 1817   / 2000   - loss = -6.665e+01 - val loss = -6.716e+01
# Epoch 1818   / 2000   - loss = -6.473e+01 - val loss = -6.766e+01
# Epoch 1819   / 2000   - loss = -6.645e+01 - val loss = -6.708e+01
# Epoch 1820   / 2000   - loss = -6.881e+01 - val loss = -6.822e+01
# Epoch 1821   / 2000   - loss = -6.634e+01 - val loss = -6.559e+01
# Epoch 1822   / 2000   - loss = -6.477e+01 - val loss = -6.762e+01
# Epoch 1823   / 2000   - loss = -6.780e+01 - val loss = -6.771e+01
# Epoch 1824   / 2000   - loss = -6.858e+01 - val loss = -6.541e+01
# Epoch 1825   / 2000   - loss = -6.921e+01 - val loss = -6.763e+01
# Epoch 1826   / 2000   - loss = -6.535e+01 - val loss = -6.870e+01
# Epoch 1827   / 2000   - loss = -6.643e+01 - val loss = -6.610e+01
# Epoch 1828   / 2000   - loss = -6.801e+01 - val loss = -6.652e+01
# Epoch 1829   / 2000   - loss = -6.782e+01 - val loss = -6.521e+01
# Epoch 1830   / 2000   - loss = -6.505e+01 - val loss = -6.826e+01
# Epoch 1831   / 2000   - loss = -6.564e+01 - val loss = -6.817e+01
# Epoch 1832   / 2000   - loss = -6.834e+01 - val loss = -6.733e+01
# Epoch 1833   / 2000   - loss = -6.690e+01 - val loss = -6.711e+01
# Epoch 1834   / 2000   - loss = -6.654e+01 - val loss = -6.841e+01
# Epoch 1835   / 2000   - loss = -6.762e+01 - val loss = -6.656e+01
# Epoch 1836   / 2000   - loss = -6.673e+01 - val loss = -6.724e+01
# Epoch 1837   / 2000   - loss = -6.615e+01 - val loss = -6.805e+01
# Epoch 1838   / 2000   - loss = -6.735e+01 - val loss = -6.525e+01
# Epoch 1839   / 2000   - loss = -6.803e+01 - val loss = -6.568e+01
# Epoch 1840   / 2000   - loss = -6.701e+01 - val loss = -6.810e+01
# Epoch 1841   / 2000   - loss = -6.699e+01 - val loss = -6.500e+01
# Epoch 1842   / 2000   - loss = -6.819e+01 - val loss = -6.750e+01
# Epoch 1843   / 2000   - loss = -6.650e+01 - val loss = -6.783e+01
# Epoch 1844   / 2000   - loss = -6.608e+01 - val loss = -6.717e+01
# Epoch 1845   / 2000   - loss = -6.678e+01 - val loss = -6.655e+01
# Epoch 1846   / 2000   - loss = -6.412e+01 - val loss = -6.827e+01
# Epoch 1847   / 2000   - loss = -6.638e+01 - val loss = -6.636e+01
# Epoch 1848   / 2000   - loss = -6.814e+01 - val loss = -6.834e+01
# Epoch 1849   / 2000   - loss = -6.716e+01 - val loss = -7.000e+01
# Epoch 1850   / 2000   - loss = -6.665e+01 - val loss = -6.719e+01
# Epoch 1851   / 2000   - loss = -6.572e+01 - val loss = -6.640e+01
# Epoch 1852   / 2000   - loss = -6.644e+01 - val loss = -6.480e+01
# Epoch 1853   / 2000   - loss = -6.701e+01 - val loss = -6.724e+01
# Epoch 1854   / 2000   - loss = -6.625e+01 - val loss = -6.666e+01
# Epoch 1855   / 2000   - loss = -6.564e+01 - val loss = -6.795e+01
# Epoch 1856   / 2000   - loss = -6.779e+01 - val loss = -6.721e+01
# Epoch 1857   / 2000   - loss = -6.787e+01 - val loss = -6.606e+01
# Epoch 1858   / 2000   - loss = -6.746e+01 - val loss = -6.667e+01
# Epoch 1859   / 2000   - loss = -6.374e+01 - val loss = -6.708e+01
# Epoch 1860   / 2000   - loss = -6.352e+01 - val loss = -6.633e+01
# Epoch 1861   / 2000   - loss = -6.821e+01 - val loss = -6.899e+01
# Epoch 1862   / 2000   - loss = -6.540e+01 - val loss = -6.798e+01
# Epoch 1863   / 2000   - loss = -6.558e+01 - val loss = -6.704e+01
# Epoch 1864   / 2000   - loss = -6.789e+01 - val loss = -6.785e+01
# Epoch 1865   / 2000   - loss = -6.524e+01 - val loss = -6.295e+01
# Epoch 1866   / 2000   - loss = -6.645e+01 - val loss = -6.692e+01
# Epoch 1867   / 2000   - loss = -6.722e+01 - val loss = -6.778e+01
# Epoch 1868   / 2000   - loss = -6.664e+01 - val loss = -6.818e+01
# Epoch 1869   / 2000   - loss = -6.433e+01 - val loss = -6.695e+01
# Epoch 1870   / 2000   - loss = -6.548e+01 - val loss = -6.310e+01
# Epoch 1871   / 2000   - loss = -6.783e+01 - val loss = -6.503e+01
# Epoch 1872   / 2000   - loss = -6.541e+01 - val loss = -6.840e+01
# Epoch 1873   / 2000   - loss = -6.578e+01 - val loss = -6.684e+01
# Epoch 1874   / 2000   - loss = -6.707e+01 - val loss = -6.690e+01
# Epoch 1875   / 2000   - loss = -6.738e+01 - val loss = -6.558e+01
# Epoch 1876   / 2000   - loss = -6.731e+01 - val loss = -6.609e+01
# Epoch 1877   / 2000   - loss = -6.821e+01 - val loss = -6.745e+01
# Epoch 1878   / 2000   - loss = -6.793e+01 - val loss = -6.802e+01
# Epoch 1879   / 2000   - loss = -6.738e+01 - val loss = -6.577e+01
# Epoch 1880   / 2000   - loss = -6.551e+01 - val loss = -6.670e+01
# Epoch 1881   / 2000   - loss = -6.410e+01 - val loss = -6.586e+01
# Epoch 1882   / 2000   - loss = -6.652e+01 - val loss = -6.502e+01
# Epoch 1883   / 2000   - loss = -6.825e+01 - val loss = -6.769e+01
# Epoch 1884   / 2000   - loss = -6.852e+01 - val loss = -6.732e+01
# Epoch 1885   / 2000   - loss = -6.670e+01 - val loss = -6.792e+01
# Epoch 1886   / 2000   - loss = -6.669e+01 - val loss = -6.538e+01
# Epoch 1887   / 2000   - loss = -6.507e+01 - val loss = -6.638e+01
# Epoch 1888   / 2000   - loss = -6.621e+01 - val loss = -6.777e+01
# Epoch 1889   / 2000   - loss = -6.423e+01 - val loss = -6.641e+01
# Epoch 1890   / 2000   - loss = -6.756e+01 - val loss = -6.782e+01
# Epoch 1891   / 2000   - loss = -6.745e+01 - val loss = -6.766e+01
# Epoch 1892   / 2000   - loss = -6.484e+01 - val loss = -6.322e+01
# Epoch 1893   / 2000   - loss = -6.752e+01 - val loss = -6.669e+01
# Epoch 1894   / 2000   - loss = -6.620e+01 - val loss = -6.597e+01
# Epoch 1895   / 2000   - loss = -6.766e+01 - val loss = -6.788e+01
# Epoch 1896   / 2000   - loss = -6.840e+01 - val loss = -6.638e+01
# Epoch 1897   / 2000   - loss = -6.808e+01 - val loss = -6.519e+01
# Epoch 1898   / 2000   - loss = -6.603e+01 - val loss = -6.462e+01
# Epoch 1899   / 2000   - loss = -6.641e+01 - val loss = -6.817e+01
# Epoch 1900   / 2000   - loss = -6.599e+01 - val loss = -6.688e+01
# Epoch 1901   / 2000   - loss = -6.701e+01 - val loss = -6.707e+01
# Epoch 1902   / 2000   - loss = -6.719e+01 - val loss = -6.658e+01
# Epoch 1903   / 2000   - loss = -6.751e+01 - val loss = -6.774e+01
# Epoch 1904   / 2000   - loss = -6.546e+01 - val loss = -6.709e+01
# Epoch 1905   / 2000   - loss = -6.763e+01 - val loss = -6.555e+01
# Epoch 1906   / 2000   - loss = -6.644e+01 - val loss = -6.480e+01
# Epoch 1907   / 2000   - loss = -6.714e+01 - val loss = -6.595e+01
# Epoch 1908   / 2000   - loss = -6.628e+01 - val loss = -6.791e+01
# Epoch 1909   / 2000   - loss = -6.821e+01 - val loss = -6.508e+01
# Epoch 1910   / 2000   - loss = -6.806e+01 - val loss = -6.705e+01
# Epoch 1911   / 2000   - loss = -6.802e+01 - val loss = -6.843e+01
# Epoch 1912   / 2000   - loss = -6.721e+01 - val loss = -6.679e+01
# Epoch 1913   / 2000   - loss = -6.885e+01 - val loss = -6.845e+01
# Epoch 1914   / 2000   - loss = -6.796e+01 - val loss = -6.622e+01
# Epoch 1915   / 2000   - loss = -6.376e+01 - val loss = -6.621e+01
# Epoch 1916   / 2000   - loss = -6.801e+01 - val loss = -6.709e+01
# Epoch 1917   / 2000   - loss = -6.703e+01 - val loss = -6.710e+01
# Epoch 1918   / 2000   - loss = -6.631e+01 - val loss = -6.449e+01
# Epoch 1919   / 2000   - loss = -6.801e+01 - val loss = -6.670e+01
# Epoch 1920   / 2000   - loss = -5.867e+01 - val loss = -6.499e+01
# Epoch 1921   / 2000   - loss = -6.546e+01 - val loss = -6.710e+01
# Epoch 1922   / 2000   - loss = -6.674e+01 - val loss = -6.768e+01
# Epoch 1923   / 2000   - loss = -6.681e+01 - val loss = -6.755e+01
# Epoch 1924   / 2000   - loss = -6.726e+01 - val loss = -6.565e+01
# Epoch 1925   / 2000   - loss = -6.692e+01 - val loss = -6.739e+01
# Epoch 1926   / 2000   - loss = -6.709e+01 - val loss = -6.774e+01
# Epoch 1927   / 2000   - loss = -6.721e+01 - val loss = -6.647e+01
# Epoch 1928   / 2000   - loss = -6.709e+01 - val loss = -6.724e+01
# Epoch 1929   / 2000   - loss = -6.555e+01 - val loss = -6.634e+01
# Epoch 1930   / 2000   - loss = -6.590e+01 - val loss = -6.753e+01
# Epoch 1931   / 2000   - loss = -6.435e+01 - val loss = -6.704e+01
# Epoch 1932   / 2000   - loss = -6.618e+01 - val loss = -6.785e+01
# Epoch 1933   / 2000   - loss = -6.645e+01 - val loss = -6.765e+01
# Epoch 1934   / 2000   - loss = -6.775e+01 - val loss = -6.823e+01
# Epoch 1935   / 2000   - loss = -6.753e+01 - val loss = -6.755e+01
# Epoch 1936   / 2000   - loss = -6.697e+01 - val loss = -6.771e+01
# Epoch 1937   / 2000   - loss = -6.673e+01 - val loss = -6.566e+01
# Epoch 1938   / 2000   - loss = -6.363e+01 - val loss = -6.558e+01
# Epoch 1939   / 2000   - loss = -6.137e+01 - val loss = -6.625e+01
# Epoch 1940   / 2000   - loss = -6.586e+01 - val loss = -6.823e+01
# Epoch 1941   / 2000   - loss = -6.565e+01 - val loss = -6.605e+01
# Epoch 1942   / 2000   - loss = -6.656e+01 - val loss = -6.597e+01
# Epoch 1943   / 2000   - loss = -6.646e+01 - val loss = -6.726e+01
# Epoch 1944   / 2000   - loss = -6.745e+01 - val loss = -6.769e+01
# Epoch 1945   / 2000   - loss = -6.567e+01 - val loss = -6.543e+01
# Epoch 1946   / 2000   - loss = -6.864e+01 - val loss = -6.620e+01
# Epoch 1947   / 2000   - loss = -6.594e+01 - val loss = -6.658e+01
# Epoch 1948   / 2000   - loss = -6.665e+01 - val loss = -6.779e+01
# Epoch 1949   / 2000   - loss = -6.734e+01 - val loss = -6.354e+01
# Epoch 1950   / 2000   - loss = -6.763e+01 - val loss = -6.580e+01
# Epoch 1951   / 2000   - loss = -6.649e+01 - val loss = -6.146e+01
# Epoch 1952   / 2000   - loss = -6.790e+01 - val loss = -6.617e+01
# Epoch 1953   / 2000   - loss = -6.765e+01 - val loss = -6.246e+01
# Epoch 1954   / 2000   - loss = -6.753e+01 - val loss = -6.730e+01
# Epoch 1955   / 2000   - loss = -6.511e+01 - val loss = -6.287e+01
# Epoch 1956   / 2000   - loss = -6.729e+01 - val loss = -6.774e+01
# Epoch 1957   / 2000   - loss = -6.690e+01 - val loss = -6.605e+01
# Epoch 1958   / 2000   - loss = -6.716e+01 - val loss = -6.775e+01
# Epoch 1959   / 2000   - loss = -6.782e+01 - val loss = -6.759e+01
# Epoch 1960   / 2000   - loss = -6.640e+01 - val loss = -6.632e+01
# Epoch 1961   / 2000   - loss = -6.901e+01 - val loss = -6.628e+01
# Epoch 1962   / 2000   - loss = -6.791e+01 - val loss = -6.775e+01
# Epoch 1963   / 2000   - loss = -6.799e+01 - val loss = -6.774e+01
# Epoch 1964   / 2000   - loss = -6.650e+01 - val loss = -6.631e+01
# Epoch 1965   / 2000   - loss = -6.557e+01 - val loss = -6.692e+01
# Epoch 1966   / 2000   - loss = -6.744e+01 - val loss = -6.439e+01
# Epoch 1967   / 2000   - loss = -6.718e+01 - val loss = -6.580e+01
# Epoch 1968   / 2000   - loss = -6.588e+01 - val loss = -6.738e+01
# Epoch 1969   / 2000   - loss = -6.866e+01 - val loss = -6.696e+01
# Epoch 1970   / 2000   - loss = -6.449e+01 - val loss = -6.566e+01
# Epoch 1971   / 2000   - loss = -6.765e+01 - val loss = -6.755e+01
# Epoch 1972   / 2000   - loss = -6.735e+01 - val loss = -6.703e+01
# Epoch 1973   / 2000   - loss = -6.727e+01 - val loss = -6.786e+01
# Epoch 1974   / 2000   - loss = -6.739e+01 - val loss = -6.753e+01
# Epoch 1975   / 2000   - loss = -6.690e+01 - val loss = -6.695e+01
# Epoch 1976   / 2000   - loss = -6.763e+01 - val loss = -6.691e+01
# Epoch 1977   / 2000   - loss = -6.709e+01 - val loss = -6.669e+01
# Epoch 1978   / 2000   - loss = -6.725e+01 - val loss = -6.620e+01
# Epoch 1979   / 2000   - loss = -6.817e+01 - val loss = -6.769e+01
# Epoch 1980   / 2000   - loss = -6.326e+01 - val loss = -6.692e+01
# Epoch 1981   / 2000   - loss = -6.794e+01 - val loss = -6.842e+01
# Epoch 1982   / 2000   - loss = -6.875e+01 - val loss = -6.784e+01
# Epoch 1983   / 2000   - loss = -6.817e+01 - val loss = -6.561e+01
# Epoch 1984   / 2000   - loss = -6.660e+01 - val loss = -6.807e+01
# Epoch 1985   / 2000   - loss = -6.738e+01 - val loss = -6.738e+01
# Epoch 1986   / 2000   - loss = -6.701e+01 - val loss = -6.663e+01
# Epoch 1987   / 2000   - loss = -6.682e+01 - val loss = -6.845e+01
# Epoch 1988   / 2000   - loss = -6.795e+01 - val loss = -6.635e+01
# Epoch 1989   / 2000   - loss = -6.758e+01 - val loss = -6.921e+01
# Epoch 1990   / 2000   - loss = -6.730e+01 - val loss = -6.664e+01
# Epoch 1991   / 2000   - loss = -6.811e+01 - val loss = -6.898e+01
# Epoch 1992   / 2000   - loss = -6.687e+01 - val loss = -6.626e+01
# Epoch 1993   / 2000   - loss = -6.651e+01 - val loss = -6.706e+01
# Epoch 1994   / 2000   - loss = -6.695e+01 - val loss = -6.653e+01
# Epoch 1995   / 2000   - loss = -6.701e+01 - val loss = -6.733e+01
# Epoch 1996   / 2000   - loss = -6.760e+01 - val loss = -6.771e+01
# Epoch 1997   / 2000   - loss = -6.827e+01 - val loss = -6.671e+01
# Epoch 1998   / 2000   - loss = -6.534e+01 - val loss = -6.733e+01
# Epoch 1999   / 2000   - loss = -6.404e+01 - val loss = -6.693e+01
# Epoch 2000   / 2000   - loss = -6.664e+01 - val loss = -6.749e+01

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(training_losses, label='training')
ax.plot(validation_losses, label='validation')
ax.grid()
ax.set_title(f'Losses')
ax.legend()
plt.show()

# %%
# retrieve posterior distribution parameters
parameters_store = pyro.get_param_store()

for name, value in parameters_store.items():
    print(f'{name} = {value:.3e}')
    
print(f'Ground truth : a = {a}, b = {b}, noise = {noise}, log noise = {torch.log(noise)}')
# Out:
# a_loc = 2.009e+00
# a_scale = 2.404e-02
# b_loc = -9.879e-01
# b_scale = 1.393e-02
# log_noise_std_loc = -2.193e+00
# log_noise_std_std = 8.361e-02
# Ground truth : a = tensor([2.], device='cuda:0'), b = tensor([-1.], device='cuda:0'), noise = tensor([0.1000], device='cuda:0'), log noise = tensor([-2.3026], device='cuda:0')

# %% [markdown]
# A `pyro.poutine` is a wrapper or context manager that intercepts and modifies the behavior of Pyro primitives such as `pyro.sample` and `pyro.param`.
#
# - `pyro.poutine.trace` runs a model and a *guide* ($q_{\phi}$) and generates a data structure called a **Trace** : RV names, sampled values, distribution used, log prob, whether the RV is observed, etc.
# - the `.nodes` attrbute of the `Trace` object is a dictionary where each key corresponds to a primitive's name.
# - the `Trace` generated is typically an input for other `pyro.poutine` such as `pyro.poutine.replay` :
#   - trace the *guide* : `posterior_trace = poutine.trace(q_phi).get_trace(X)`
#   - replay the model so it uses the samples from $q_{\phi}$ : `with poutine.replay(trace=posterior_trace): predicted_y_vector = model(X, y=None)`
#
# The `trace` poutine can be used as a function wrapper or a context manager:
# - **as a wrapper** : `guide_trace = pyro.poutine.trace(posterior_sampler_guide).get_trace(X_new)`
# - **as a context manager** : `with pyro.poutine.trace() as tr:
# trace = tr.get_trace()`
#
# NB : one can code a specific `posterior_sampler` similar to the *guide* for the `Trace` execution : this can be done to 1/ clarify the separation between the training objective of the *guide* and the sampling objective of the `posterior_sampler`, and 2/ remove training-specific elements used in the *guide* and that have no value when sampling.

# %%
# here, we want to draw samples from the trained model on known X's

import pyro.poutine as poutine

N_SAMPLES=100
N_POINTS = X.shape[0]

# place holder for predictions
y_preds = torch.zeros((N_POINTS, N_SAMPLES)).to(device)

for s in range(N_SAMPLES):
    # STEP 1: Trace the execution of the prediction guide.
    # The trace records the *value* of the sampled parameters (a, b, log_noise_std).
    # posterior_trace = poutine.trace(posterior_sampler).get_trace(X)
    # NB : here we used the q_phi guide/approximate posterior, and 
    #       did not write a specific simpler posterior sampler
    posterior_trace = poutine.trace(q_phi).get_trace(X)
    
    # STEP 2: Use the Replay Poutine on the Model.
    # This forces the Model to use the parameter values recorded in guide_trace.
    with poutine.replay(trace=posterior_trace):
        # STEP 3: Execute the Model to draw a prediction.
        # Calling model(X) with y=None tells the 'obs' site to draw a sample 
        # (the predicted y) using the replayed (fixed) parameters.
        predicted_y_vector = model(X, y=None) 
    
    # STEP 4: Store the resulting vector of predictions for all N_POINTS
    y_preds[:, s] = predicted_y_vector.squeeze()

print(f"Finished sampling {N_SAMPLES} predictive vectors.")
# Out:
# Finished sampling 100 predictive vectors.

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(X.cpu(),y.cpu(), marker='x', label='ground truth')
ax.grid()
ax.set_title(f'posterior predictions with SVI')
for s in range(N_SAMPLES):
    ax.scatter(X.cpu(), y_preds[:,s].detach().cpu(), alpha=0.05, color='green', marker='.')
plt.show()

# %% [markdown]
# <div style="background-color: #008B8B; padding: 15px; border-radius: 5px; font-size: 20px; color: black; font-weight: bold;">
# 3 : learnable posterior distributions with MCMC
# </div>
#
# Now we still posit that the parameters are R.V. and use MCMC methods to sample the true posterior distributions.
#
# The class is `MCMC`with (among others) the following arguments:
# - `kernel` : type `MCMCKernel` : can be NUTS, HMC, RWMH (random walk Metropolis Hastings...)
# - `num_samples` : number of samples wanted after warmup/burn-in
# - `warmup_steps` : number of warm up steps to have the Markov Chain converge
# - `jit_compile` : If True, uses PyTorch's JIT compiler to speed up the model's forward and gradient calculations. Requires a static computational graph. Defaults to False.
# - `disable_progbar` : If True, suppresses the tqdm progress bar during the MCMC.run() call. Defaults to False.

# %% [markdown]
# Zoom on JIT compilation:
#
# 1. What JIT Compilation Does
# **Tracing**: When `jit_compile=True`, the Pyro/PyTorch system executes the core computational graph of the NUTS algorithm (which includes the gradient calculations over your model) once, and the JIT compiler records (or "traces") all the operations performed on the tensors.
# **Optimization**: This recorded graph is then optimized and compiled into a highly efficient execution unit.
# **Execution**: Subsequent steps of the NUTS chain use this compiled code block instead of re-interpreting the Python/PyTorch code every time.
#
# 2. JIT's Requirement: Static Graph
# The primary constraint of using `jit_compile=True` is that your model and guide must be traceable. This means:
# - No Data-Dependent Control Flow: You cannot have conditional logic (if/else statements, loops) where the condition depends on the data (tensor values) within the model that changes per iteration. The computational graph must be static.
# - Static Shapes: Tensor sizes should generally remain constant during the MCMC run.
# - For simple models like Bayesian linear regression, 'jit_compile=True' usually works without issue and provides a substantial speedup, especially when using a GPU.

# %%
# reset the Store parameters
pyro.clear_param_store()

# %%
# STEP 1 : define the NUTS kernel - takes the generative model itself.
nuts_kernel = NUTS(
    model=model,
    jit_compile=True, # True for speed, False for debugging
)

# %%
# STEP 2 : define a MCMC sampler with the above kernel
# does NOT use the model. This is merely the executor of the MCMCKernel
N_MCMC_SAMPLES = 1000
N_BURNIN = 100

MCMC_runner = MCMC(
    kernel=nuts_kernel,
    num_samples=N_MCMC_SAMPLES,
    warmup_steps=N_BURNIN,
    num_chains=1,
    initial_params=None
)

# %%
# STEP3 : run the sampler
MCMC_runner.run(X,y)
# Out:
# Sample: 100%|██████████| 1100/1100 [00:06, 177.53it/s, step size=3.45e-01, acc. prob=0.880]

# %%
# STEP 4 : Extract and analyse the samples

# get samples
posterior_samples = MCMC_runner.get_samples()

a_samples = posterior_samples.get('a')
b_samples = posterior_samples.get('b')
log_noise_std_samples = posterior_samples.get('log_noise_std')
noise_std_samples = torch.exp(log_noise_std_samples)

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(21,6))

dict = {
    'a' : a_samples,
    'b' : b_samples,
    'noise_std_samples' : noise_std_samples
}

for i, (name, data) in enumerate(dict.items()):
    samples = data.cpu().numpy()
    sample_mean = samples.mean()
    sample_ci_low = torch.quantile(data, 0.025).item()
    sample_ci_high = torch.quantile(data, 0.975).item()
    
    sns.histplot(data=samples, bins=50, kde=True, label=f'{name}', ax=ax[i])
    ax[i].vlines([sample_mean, sample_ci_low, sample_ci_high],
                ymin=0, ymax=ax[i].get_ylim()[1],
                colors=['k', 'orange', 'orange'],
                linestyles=['-', '--', '--'],
                label='mean/95% CI')
    ax[i].grid()
    ax[i].legend()
    ax[i].set_title(f"Posterior samples of {name}")
    
print(f'Ground truth : a = {a.item():.3f}, b = {b.item():.3f}, noise = {noise.item():.3f}')
# Out:
# Ground truth : a = 2.000, b = -1.000, noise = 0.100

# %%
# STEP 5 : POSTERIOR PREDICTIVE SAMPLING

# here we use some boilerplate code to reconstruct a trace out of the samples,
# so we can use the poutine.replay afterwards
def make_trace_from_mcmc_samples(i):
    
    # A clean approach is to use a trace template
    def latent_sampler_template():
        # This MUST mirror the latent pyro.sample sites in your actual model
        _ = pyro.sample("a", dist.Normal(0, 1)) 
        _ = pyro.sample("b", dist.Normal(0, 1))
        _ = pyro.sample("log_noise_std", dist.Normal(0, 1))

    # Run the template function to get a VALID trace graph
    template_trace = poutine.trace(latent_sampler_template).get_trace()
    
    # loop over all the latent variables
    for name in template_trace.nodes:
        # Check if the node is a latent variable we sampled in MCMC
        if name in posterior_samples and template_trace.nodes[name]['type'] == 'sample':
            
            # Get the MCMC sample
            mcmc_sample_value = posterior_samples[name][i].squeeze()
            
            # Replace the value in the template trace with the MCMC sample
            template_trace.nodes[name]['value'] = mcmc_sample_value
            
            # Ensure no observation (should already be True, but for safety)
            template_trace.nodes[name]['is_observed'] = False
            
            # Ensure the log_prob is correctly sized (or zeroed out)
            template_trace.nodes[name]['log_prob'] = torch.zeros_like(mcmc_sample_value)

    # 3. Return the modified, but structurally VALID, trace
    return template_trace

# %%
# STEP 5 - continued

# place holder for predictions
y_preds = torch.zeros((N_POINTS, N_MCMC_SAMPLES)).to(device)

# loop on the samples, draw a prediction at for each set of posterior a,b,noise
for i in range(N_MCMC_SAMPLES):
    # form the Trace associated to the i-th sample
    mcmc_trace = make_trace_from_mcmc_samples(i)
    # draw an output sample with the posterior samples
    with poutine.replay(trace=mcmc_trace):
        predicted_y_vector = model(X, y=None)
    # store
    y_preds[:,i] = predicted_y_vector.squeeze()

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(X.cpu(),y.cpu(), marker='x', label='ground truth')
ax.grid()
ax.set_title(f'posterior predictions with MCMC')
for s in range(N_SAMPLES):
    ax.scatter(X.cpu(), y_preds[:,s].detach().cpu(), alpha=0.05, color='green', marker='.')
plt.show()
